# %% [markdown]
# <a href="https://colab.research.google.com/github/josemanuelvinhas/MarvelRecomverse/blob/main/MarvelRecomverse_Sistema_de_Recomendaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**0. Sistema de Recomendación**

# %% [markdown]
# En este Notebook se realiza la implementación del sistema de recomendación de la aplicación.
#
# En el primer punto se calcula la matriz de parecidos entre todos los personajes del dataset. Se realiza a modo de prueba, ya que no es necesario para la aplicación.
#
# En el segundo punto se buscan los personajes más similares a una persona en función de dos criterios distintos:
# * Descripción
# * Descripción + Valoración Comentarios + Valoración Directa (Likes) + Valoración Media Comentarios
#
# El uso de distintos criterios se realiza únicamente para comprobar como afectan al resultado final.
#
# *NOTA: el dataset que se empleará está disponible [aquí](https://github.com/josemanuelvinhas/MarvelRecomverse/blob/main/marvel.csv)*

# %% [markdown]
# #**1. Cálculo de la matriz de parecidos**

# %% [markdown]
# ##**1.1 Preprocesado del dataset**

# %% [markdown]
# Para poder trabajar con los datos se deberá realizar un preprocesado de las descripciones.
#
# El dataset con el que se trabaja contiene una colección de 281 personajes. Cada uno tiene dos campos:
#
# 1.   *name*: nombre del personaje
# 2.   *description*: descripcion del personaje
#
# Se hará uso de la librería *pandas* para el preprocesado. A continuación se carga el csv con los datos

# %%
import pandas as pd

originalData = pd.read_csv('marvel.csv')
originalData
# Out:
#                            name                                        description
# 0                  A-Bomb (HAS)  Rick Jones has been Hulk's best bud since day ...
# 1                        A.I.M.  AIM is a terrorist organization bent on destro...
# 2    Abomination (Emil Blonsky)  Formerly known as Emil Blonsky, a spy of Sovie...
# 3                  Adam Warlock  Adam Warlock is an artificially created human ...
# 4                Agent X (Nijo)  Originally a partner of the mind-altering assa...
# ..                          ...                                                ...
# 276                       Zarek  Zarek is a member of the Kree race with no sup...
# 277                      Zodiak  Twelve demons merged with Norman Harrison, who...
# 278        Zombie (Simon Garth)  War hero Simon Garth was turned into a zombie ...
# 279                       Zuras         Zuras was once the leader of the Eternals.
# 280                       Zzzax  A chain reaction in an atomic reactor, a resul...
#
# [281 rows x 2 columns]

# %% [markdown]
# A continuación se llevará a cabo el preprocesado, en la que se usarán 3 técnicas:
#
# 1.   ***Tokenization***: división del texto en palabras
# 2.   Eliminación de ***stopwords***
# 3. ***Stemmization***: permite la obtención de la raíz de cada palabra sin que el resultado sea una palabra real.

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
nltk.download('punkt')
nltk.download('stopwords')

ps = PorterStemmer()

preprocessedText = []

for row in originalData.itertuples():
    text = word_tokenize(row[2]) ## indice de la columna que contiene la descripcion
    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [ps.stem(w) for w in text if not w in stops and w.isalnum()]
    text = " ".join(text)
    
    preprocessedText.append(text)

preprocessedData = originalData
preprocessedData['processed_text'] = preprocessedText

preprocessedData
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                            name  ...                                     processed_text
# 0                  A-Bomb (HAS)  ...  rick jone hulk best bud sinc day one friend te...
# 1                        A.I.M.  ...             aim terrorist organ bent destroy world
# 2    Abomination (Emil Blonsky)  ...  formerli known emil blonski spi soviet yugosla...
# 3                  Adam Warlock  ...  adam warlock artifici creat human born cocoon ...
# 4                Agent X (Nijo)  ...  origin partner assassin black swan nijo spi de...
# ..                          ...  ...                                                ...
# 276                       Zarek  ...  zarek member kree race superhuman abil special...
# 277                      Zodiak  ...  twelv demon merg norman harrison soon adopt gu...
# 278        Zombie (Simon Garth)  ...  war hero simon garth turn zombi secretari layl...
# 279                       Zuras  ...                                  zura leader etern
# 280                       Zzzax  ...  A chain reaction atom reactor result terrorist...
#
# [281 rows x 3 columns]

# %% [markdown]
# ##**1.2 Creación de la bolsa de palabras (BoW) con TF-IDF**

# %% [markdown]
# Se parte de los datos almacenados en "preprocessedData", en donde para cada personaje existe un campo 'preprocessed_text' que contiene la descripción preprocesada.
#
# El objetivo es transformar todos los textos de sinopsis en vectores de frecuencias (Bag of words), aplicando además la ponderación TF-IDF para los valores de dichas frecuencias.
#
# El paquete sklearn ofrece una clase llamada *TfidfVectorizer* que crea automáticamente la matriz compuesta por todos los vectores de frecuencias ponderados a partir de un array de textos (preprocessedData['processed_text'])
#
# Si se quiere emplear la bolsa de palabras sin ponderación TF-IDF puede usarse la clase *CountVectorized* del mismo paquete

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

bagOfWordsModel = TfidfVectorizer()
bagOfWordsModel.fit(preprocessedData['processed_text'])
textsBoW= bagOfWordsModel.transform(preprocessedData['processed_text'])
print("Finished")
# Out:
# Finished

# %%
textsBoW.shape
# Out:
# (281, 2283)

# %%
print(textsBoW)
# Out:
#   (0, 2137)	0.130889104582123
#   (0, 2058)	0.14217279372193212
#   (0, 2004)	0.22205823661448335
#   (0, 1974)	0.22205823661448335
#   (0, 1894)	0.1961840975559547
#   (0, 1790)	0.1961840975559547
#   (0, 1779)	0.1752944840330487
#   (0, 1634)	0.22205823661448335
#   (0, 1505)	0.10190245579244313
#   (0, 1404)	0.11629865466340347
#   (0, 1174)	0.16198034620346324
#   (0, 1086)	0.22205823661448335
#   (0, 968)	0.1468449451157794
#   (0, 840)	0.20692283552679946
#   (0, 816)	0.17030995849742606
#   (0, 797)	0.14942034497452006
#   (0, 695)	0.1752944840330487
#   (0, 647)	0.16198034620346324
#   (0, 537)	0.1878544852619919
#   (0, 496)	0.1878544852619919
#   (0, 475)	0.22205823661448335
#   (0, 284)	0.20692283552679946
#   (0, 251)	0.22205823661448335
#   (0, 242)	0.1878544852619919
#   (0, 214)	0.1752944840330487
#   :	:
#   (278, 818)	0.30506443106319997
#   (278, 81)	0.2225292018497309
#   (279, 2282)	0.6554139206650713
#   (279, 1148)	0.49150479114816825
#   (279, 669)	0.5734593559066198
#   (280, 1993)	0.22286926032113236
#   (280, 1726)	0.25226282639126546
#   (280, 1662)	0.25226282639126546
#   (280, 1623)	0.2134066455942286
#   (280, 1577)	0.25226282639126546
#   (280, 1576)	0.25226282639126546
#   (280, 1346)	0.23506869247776788
#   (280, 970)	0.159087426424004
#   (280, 868)	0.19913822007758497
#   (280, 775)	0.16974465400745184
#   (280, 695)	0.19913822007758497
#   (280, 647)	0.18401307952409543
#   (280, 620)	0.25226282639126546
#   (280, 456)	0.16408212818086607
#   (280, 340)	0.25226282639126546
#   (280, 255)	0.22286926032113236
#   (280, 158)	0.25226282639126546
#   (280, 157)	0.23506869247776788
#   (280, 22)	0.22286926032113236
#   (280, 17)	0.23506869247776788

# %%
bagOfWordsModel.get_feature_names()
# Out:
# ['13',
#  '1910',
#  '1930',
#  '1931',
#  '1940',
#  '19th',
#  '21st',
#  '31st',
#  '53rd',
#  '60',
#  'abandon',
#  'abduct',
#  'abil',
#  'abl',
#  'abomin',
#  'abraham',
#  'abruptli',
#  'absorb',
#  'abus',
#  'academ',
#  'acceler',
#  'access',
#  'accident',
#  'accomplish',
#  'accord',
#  'account',
#  'accustom',
#  'acolyt',
#  'acquir',
#  'acrobat',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'actress',
#  'ad',
#  'adam',
#  'adamantium',
#  'adapt',
#  'add',
#  'admiss',
#  'adolesc',
#  'adopt',
#  'adrian',
#  'adulthood',
#  'advanc',
#  'advantag',
#  'adventur',
#  'aegi',
#  'affect',
#  'affin',
#  'affluent',
#  'africa',
#  'african',
#  'after',
#  'age',
#  'agenc',
#  'agent',
#  'ago',
#  'agre',
#  'aid',
#  'aim',
#  'air',
#  'airdrop',
#  'albeit',
#  'alberta',
#  'alex',
#  'alexand',
#  'alia',
#  'alien',
#  'alik',
#  'all',
#  'allegi',
#  'alli',
#  'allow',
#  'almost',
#  'alon',
#  'along',
#  'alongsid',
#  'alpha',
#  'alreadi',
#  'also',
#  'alter',
#  'altern',
#  'although',
#  'alvarez',
#  'alway',
#  'amahl',
#  'amaz',
#  'america',
#  'american',
#  'among',
#  'amora',
#  'amount',
#  'amphibi',
#  'amulet',
#  'amun',
#  'an',
#  'anathema',
#  'ancient',
#  'and',
#  'andrea',
#  'android',
#  'andromeda',
#  'andsew',
#  'angela',
#  'angelo',
#  'anger',
#  'angrier',
#  'anim',
#  'anoth',
#  'anton',
#  'anyon',
#  'anyth',
#  'apart',
#  'apocalyps',
#  'appar',
#  'appear',
#  'appetit',
#  'appoint',
#  'apprehend',
#  'approach',
#  'aralun',
#  'araña',
#  'arch',
#  'archer',
#  'area',
#  'arguabl',
#  'arliss',
#  'arm',
#  'armi',
#  'armor',
#  'arnim',
#  'aros',
#  'around',
#  'arrow',
#  'art',
#  'artifici',
#  'artist',
#  'as',
#  'asgard',
#  'asgardian',
#  'ashida',
#  'asia',
#  'ask',
#  'aspect',
#  'assassin',
#  'asset',
#  'assign',
#  'assist',
#  'associ',
#  'assum',
#  'astrolog',
#  'ate',
#  'athlet',
#  'atla',
#  'atlanti',
#  'atom',
#  'attack',
#  'attempt',
#  'attitud',
#  'aunt',
#  'australia',
#  'australian',
#  'author',
#  'ava',
#  'aveng',
#  'averag',
#  'await',
#  'awar',
#  'award',
#  'away',
#  'awesom',
#  'ayala',
#  'azazel',
#  'back',
#  'backbon',
#  'badilino',
#  'badli',
#  'balanc',
#  'ball',
#  'band',
#  'bank',
#  'banner',
#  'banshe',
#  'baron',
#  'barton',
#  'base',
#  'basi',
#  'battl',
#  'battlefield',
#  'be',
#  'beacher',
#  'beast',
#  'beat',
#  'becam',
#  'becom',
#  'beehiv',
#  'beemont',
#  'beetl',
#  'beg',
#  'began',
#  'begin',
#  'behalf',
#  'behav',
#  'behavior',
#  'behemoth',
#  'behest',
#  'believ',
#  'belong',
#  'belt',
#  'ben',
#  'benjamin',
#  'bent',
#  'best',
#  'beta',
#  'betray',
#  'better',
#  'biblic',
#  'big',
#  'bigger',
#  'biggest',
#  'billi',
#  'billion',
#  'billionair',
#  'biochemist',
#  'bird',
#  'birj',
#  'birth',
#  'bishop',
#  'bison',
#  'bit',
#  'bite',
#  'bitten',
#  'black',
#  'blackfoot',
#  'blacki',
#  'blast',
#  'bless',
#  'blind',
#  'blonski',
#  'blood',
#  'blue',
#  'bob',
#  'bodi',
#  'bomb',
#  'bond',
#  'border',
#  'born',
#  'bounti',
#  'bourn',
#  'bowl',
#  'boxer',
#  'boy',
#  'brag',
#  'brain',
#  'brainwash',
#  'brave',
#  'brazilian',
#  'breach',
#  'breadth',
#  'break',
#  'breakdown',
#  'breath',
#  'brethren',
#  'brian',
#  'bright',
#  'brilliant',
#  'britain',
#  'british',
#  'broadcast',
#  'brock',
#  'broker',
#  'brood',
#  'brooklyn',
#  'brother',
#  'brotherhood',
#  'brought',
#  'bruce',
#  'bruiser',
#  'brunnhild',
#  'brutal',
#  'brutish',
#  'bu',
#  'bud',
#  'bugl',
#  'build',
#  'built',
#  'bulldoz',
#  'bulli',
#  'burp',
#  'burst',
#  'but',
#  'buzzard',
#  'by',
#  'ca',
#  'cabal',
#  'cabin',
#  'cabl',
#  'calcuttan',
#  'caldwel',
#  'calgari',
#  'call',
#  'cambodia',
#  'came',
#  'cameron',
#  'camp',
#  'canada',
#  'canadian',
#  'canaver',
#  'candid',
#  'cannon',
#  'cape',
#  'capit',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'card',
#  'career',
#  'cargo',
#  'carmella',
#  'carmilla',
#  'carnag',
#  'carniv',
#  'carol',
#  'carson',
#  'cartoon',
#  'carv',
#  'cassi',
#  'cassidi',
#  'cast',
#  'caught',
#  'caus',
#  'celebr',
#  'celesti',
#  'cell',
#  'cellmat',
#  'centuri',
#  'certainli',
#  'chain',
#  'challeng',
#  'chamber',
#  'champion',
#  'chan',
#  'chanc',
#  'chang',
#  'channel',
#  'chao',
#  'chapman',
#  'charact',
#  'charg',
#  'chariti',
#  'charl',
#  'chase',
#  'chast',
#  'chemic',
#  'chemist',
#  'chief',
#  'child',
#  'childhood',
#  'children',
#  'chill',
#  'chin',
#  'choic',
#  'choos',
#  'chord',
#  'chosen',
#  'chri',
#  'christoph',
#  'church',
#  'circl',
#  'circuitri',
#  'citi',
#  'civil',
#  'civilian',
#  'claim',
#  'clan',
#  'clandestin',
#  'clash',
#  'class',
#  'claw',
#  'clint',
#  'cloak',
#  'clone',
#  'close',
#  'club',
#  'clutch',
#  'coat',
#  'cocoon',
#  'codenam',
#  'cold',
#  'colleen',
#  'colleg',
#  'collin',
#  'combat',
#  'combin',
#  'come',
#  'command',
#  'comment',
#  'commiss',
#  'commit',
#  'commun',
#  'compani',
#  'compassion',
#  'compet',
#  'competit',
#  'complex',
#  'composit',
#  'compound',
#  'comput',
#  'concept',
#  'concuss',
#  'conduct',
#  'confront',
#  'connect',
#  'conquest',
#  'conscious',
#  'consid',
#  'conson',
#  'constant',
#  'constantli',
#  'construct',
#  'consum',
#  'contact',
#  'contain',
#  'contempt',
#  'contest',
#  'continu',
#  'control',
#  'controversi',
#  'convers',
#  'convinc',
#  'copi',
#  'core',
#  'corner',
#  'corpor',
#  'corrupt',
#  'cosmic',
#  'cosmo',
#  'cost',
#  'costa',
#  'costum',
#  'could',
#  'coulson',
#  'countless',
#  'countri',
#  'courag',
#  'cousin',
#  'covert',
#  'cowardli',
#  'craft',
#  'craig',
#  'cranki',
#  'crash',
#  'crazi',
#  'creat',
#  'creation',
#  'creatur',
#  'credit',
#  'crew',
#  'cri',
#  'crime',
#  'crimelord',
#  'crimin',
#  'crimson',
#  'crisi',
#  'crowbar',
#  'crystal',
#  'crème',
#  'cube',
#  'cuckoo',
#  'cull',
#  'cult',
#  'cure',
#  'curl',
#  'current',
#  'curs',
#  'custom',
#  'cybel',
#  'cybernet',
#  'cyclop',
#  'da',
#  'dad',
#  'dagger',
#  'daili',
#  'dancer',
#  'danni',
#  'danver',
#  'dare',
#  'daredevil',
#  'darkhawk',
#  'darnel',
#  'daughter',
#  'davi',
#  'david',
#  'day',
#  'db',
#  'de',
#  'dead',
#  'deadli',
#  'deadpool',
#  'deal',
#  'dealer',
#  'death',
#  'debut',
#  'decad',
#  'decay',
#  'deceas',
#  'decid',
#  'decor',
#  'dedic',
#  'dee',
#  'deem',
#  'deep',
#  'defeat',
#  'defect',
#  'defend',
#  'defens',
#  'deiti',
#  'del',
#  'delroy',
#  'delvadian',
#  'demara',
#  'demogoblin',
#  'demon',
#  'demonstr',
#  'depart',
#  'deriv',
#  'descend',
#  'describ',
#  'design',
#  'despit',
#  'despond',
#  'despot',
#  'destin',
#  'destroy',
#  'destruct',
#  'detail',
#  'determin',
#  'devast',
#  'develop',
#  'deviat',
#  'devic',
#  'devil',
#  'devis',
#  'devour',
#  'diamond',
#  'dictat',
#  'dictatorship',
#  'die',
#  'differ',
#  'dimens',
#  'dinosaur',
#  'direct',
#  'directli',
#  'director',
#  'dirk',
#  'disapprov',
#  'disast',
#  'discard',
#  'discipl',
#  'discov',
#  'disgruntl',
#  'disguis',
#  'distanc',
#  'distant',
#  'disturb',
#  'divert',
#  'doctor',
#  'dog',
#  'doll',
#  'dollar',
#  'don',
#  'donat',
#  'donna',
#  'doom',
#  'dorca',
#  'doreen',
#  'dormammu',
#  'dorrek',
#  'dose',
#  'downsiz',
#  'dozen',
#  'draft',
#  'drago',
#  'dragon',
#  'drax',
#  'dream',
#  'drew',
#  'drug',
#  'dub',
#  'ductor',
#  'dude',
#  'due',
#  'duplic',
#  'durabl',
#  'dure',
#  'dwarfish',
#  'dynamo',
#  'dyne',
#  'eager',
#  'earli',
#  'earlier',
#  'earn',
#  'earth',
#  'earthl',
#  'eas',
#  'eat',
#  'eddi',
#  'edi',
#  'edward',
#  'effect',
#  'effort',
#  'ego',
#  'eight',
#  'eighti',
#  'eisenhow',
#  'elder',
#  'eldest',
#  'electrolyt',
#  'electron',
#  'elektra',
#  'elev',
#  'elimin',
#  'eliot',
#  'elit',
#  'elizabeth',
#  'elli',
#  'embark',
#  'embodi',
#  'emerg',
#  'emil',
#  'emma',
#  'emot',
#  'emperor',
#  'empir',
#  'employ',
#  'empow',
#  'enabl',
#  'enamor',
#  'enchant',
#  'encount',
#  'end',
#  'endow',
#  'endur',
#  'enemi',
#  'energi',
#  'enforc',
#  'engin',
#  'english',
#  'enhanc',
#  'enigmat',
#  'enlist',
#  'enough',
#  'enrol',
#  'ensur',
#  'enthusiasm',
#  'enthusiast',
#  'entir',
#  'entiti',
#  'envi',
#  'environ',
#  'ero',
#  'escap',
#  'eskimo',
#  'especi',
#  'espinosa',
#  'esteem',
#  'etern',
#  'european',
#  'eve',
#  'even',
#  'event',
#  'eventu',
#  'ever',
#  'everett',
#  'everi',
#  'everyth',
#  'evil',
#  'evolutionari',
#  'exact',
#  'exactli',
#  'excalibur',
#  'except',
#  'exchang',
#  'excit',
#  'execution',
#  'exhibit',
#  'exist',
#  'exorc',
#  'experi',
#  'experienc',
#  'expert',
#  'explor',
#  'explos',
#  'expos',
#  'exposur',
#  'extend',
#  'extent',
#  'extermin',
#  'extra',
#  'extract',
#  'extranorm',
#  'extraordinari',
#  'eye',
#  'fabl',
#  'face',
#  'facsimil',
#  'fact',
#  'faction',
#  'facto',
#  'fail',
#  'fairli',
#  'falcon',
#  'fall',
#  'fallen',
#  'fals',
#  'falsworth',
#  'faltin',
#  'famili',
#  'famou',
#  'fan',
#  'fantast',
#  'farouk',
#  'fast',
#  'fatal',
#  'fate',
#  'father',
#  'favor',
#  'fbi',
#  'fear',
#  'fearless',
#  'feder',
#  'feel',
#  'feet',
#  'felin',
#  'fell',
#  'fellow',
#  'felt',
#  'femal',
#  'feroci',
#  'fianc',
#  'field',
#  'fierc',
#  'fight',
#  'fighter',
#  'figur',
#  'file',
#  'fill',
#  'film',
#  'find',
#  'fire',
#  'firearm',
#  'first',
#  'fisk',
#  'fission',
#  'fist',
#  'fit',
#  'five',
#  'fixer',
#  'flamboy',
#  'flame',
#  'flash',
#  'flashi',
#  'flechett',
#  'fled',
#  'fli',
#  'flight',
#  'flock',
#  'focus',
#  'foe',
#  'follow',
#  'fond',
#  'for',
#  'forc',
#  'ford',
#  'foretold',
#  'forg',
#  'form',
#  'former',
#  'formerli',
#  'formid',
#  'formula',
#  'fought',
#  'found',
#  'foundat',
#  'founder',
#  'four',
#  'fox',
#  'frail',
#  'franklin',
#  'freak',
#  'freakish',
#  'free',
#  'freedom',
#  'friction',
#  'friend',
#  'friendship',
#  'fritz',
#  'front',
#  'frost',
#  'frustrat',
#  'fulfil',
#  'full',
#  'fulli',
#  'fun',
#  'function',
#  'fund',
#  'furi',
#  'futur',
#  'gain',
#  'galactu',
#  'galaxi',
#  'gallio',
#  'game',
#  'gamma',
#  'gamora',
#  'garden',
#  'gargan',
#  'garrett',
#  'garth',
#  'garthwait',
#  'gath',
#  'gather',
#  'gatl',
#  'gauntlet',
#  'gave',
#  'gaveedra',
#  'gener',
#  'genet',
#  'genghi',
#  'geni',
#  'geniu',
#  'genius',
#  'georg',
#  'german',
#  'germani',
#  'get',
#  'ghost',
#  'giant',
#  'gibney',
#  'gift',
#  'gigantu',
#  'girl',
#  'girlfriend',
#  'give',
#  'given',
#  'gleason',
#  'glenn',
#  'glue',
#  'go',
#  'god',
#  'goddess',
#  'godfath',
#  'goe',
#  'gold',
#  'goliath',
#  'golmen',
#  'good',
#  'got',
#  'govern',
#  'graduat',
#  'graft',
#  'grandeur',
#  'grandfath',
#  'grandmast',
#  'grandmoth',
#  'grant',
#  'grave',
#  'great',
#  'greatest',
#  'green',
#  'greer',
#  'gregor',
#  'grew',
#  'grey',
#  'grimm',
#  'groot',
#  'grotesqu',
#  'group',
#  'groupi',
#  'grow',
#  'grown',
#  'guard',
#  'guardian',
#  'guardsmen',
#  'guid',
#  'guido',
#  'guilt',
#  'guis',
#  'gun',
#  'gunnar',
#  'guy',
#  'gwen',
#  'gyp',
#  'hair',
#  'half',
#  'hammer',
#  'hand',
#  'hank',
#  'happen',
#  'har',
#  'harada',
#  'hard',
#  'hardest',
#  'harlem',
#  'harmon',
#  'harrelson',
#  'harrison',
#  'harsh',
#  'hate',
#  'hawkey',
#  'he',
#  'head',
#  'heal',
#  'heart',
#  'heather',
#  'heavili',
#  'hector',
#  'heighten',
#  'heir',
#  'held',
#  'hell',
#  'hellfir',
#  'hellip',
#  'helmet',
#  'helmut',
#  'help',
#  'henri',
#  'her',
#  'herald',
#  'herman',
#  'hero',
#  'heroic',
#  'hi',
#  'hidden',
#  'hide',
#  'high',
#  'highli',
#  'hire',
#  'hiroshima',
#  'hit',
#  'hobgoblin',
#  'hogzilla',
#  'hold',
#  'holograph',
#  'home',
#  'homeland',
#  'homework',
#  'homo',
#  'hone',
#  'honor',
#  'hook',
#  'hope',
#  'hopeless',
#  'hord',
#  'horrif',
#  'horrifi',
#  'horseman',
#  'host',
#  'hostag',
#  'hound',
#  'hous',
#  'howev',
#  'howlett',
#  'hudson',
#  'huge',
#  'hulk',
#  'hulkbust',
#  'human',
#  'humankind',
#  'humanoid',
#  'hunter',
#  'hurt',
#  'husband',
#  'hybrid',
#  'hydra',
#  'hydraul',
#  'hyperact',
#  'idea',
#  'ident',
#  'ii',
#  'il',
#  'ill',
#  'illeg',
#  'illegitim',
#  'illinoi',
#  'imag',
#  'imbecil',
#  'immatur',
#  'immedi',
#  'immigr',
#  'immort',
#  'impenetr',
#  'imperi',
#  'implant',
#  'imprint',
#  'imprison',
#  'improvis',
#  ...]

# %%
bagOfWordsModel.get_feature_names()[1005]
# Out:
# 'includ'

# %% [markdown]
# #**2 Búsqueda de los personajes más similares a una persona**

# %% [markdown]
# ##**2.1 Basado únicamente en descripción**

# %% [markdown]
# Para realizar este proceso hay que realizar todo el proceso anterior incluyendo a la persona con su descripción. De esta forma, se calculará la distancia entre el usuario y todos los personajes.

# %% [markdown]
# En la siguiente celda se debe intrroducir el nombre y la descripción con la que se quiera calcular la distancia

# %%
nombre = "Pepe" #Introducir nombre
descripcion = "Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist" #Descripcion

# %% [markdown]
# Se realiza el mismo proceso que en el punto 1

# %%
import pandas as pd

originalData = pd.read_csv('marvel.csv')
originalData = originalData.append({'name' : nombre, 'description' : descripcion}, ignore_index=True)
originalData
# Out:
#                            name                                        description
# 0                  A-Bomb (HAS)  Rick Jones has been Hulk's best bud since day ...
# 1                        A.I.M.  AIM is a terrorist organization bent on destro...
# 2    Abomination (Emil Blonsky)  Formerly known as Emil Blonsky, a spy of Sovie...
# 3                  Adam Warlock  Adam Warlock is an artificially created human ...
# 4                Agent X (Nijo)  Originally a partner of the mind-altering assa...
# ..                          ...                                                ...
# 277                      Zodiak  Twelve demons merged with Norman Harrison, who...
# 278        Zombie (Simon Garth)  War hero Simon Garth was turned into a zombie ...
# 279                       Zuras         Zuras was once the leader of the Eternals.
# 280                       Zzzax  A chain reaction in an atomic reactor, a resul...
# 281                        Pepe  Pepe was once the leader of the Eternals. He i...
#
# [282 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
nltk.download('punkt')
nltk.download('stopwords')

ps = PorterStemmer()

preprocessedText = []

for row in originalData.itertuples():
    text = word_tokenize(row[2]) ## indice de la columna que contiene la descripcion
    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [ps.stem(w) for w in text if not w in stops and w.isalnum()]
    text = " ".join(text)
    
    preprocessedText.append(text)

preprocessedData = originalData
preprocessedData['processed_text'] = preprocessedText

preprocessedData
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                            name  ...                                     processed_text
# 0                  A-Bomb (HAS)  ...  rick jone hulk best bud sinc day one friend te...
# 1                        A.I.M.  ...             aim terrorist organ bent destroy world
# 2    Abomination (Emil Blonsky)  ...  formerli known emil blonski spi soviet yugosla...
# 3                  Adam Warlock  ...  adam warlock artifici creat human born cocoon ...
# 4                Agent X (Nijo)  ...  origin partner assassin black swan nijo spi de...
# ..                          ...  ...                                                ...
# 277                      Zodiak  ...  twelv demon merg norman harrison soon adopt gu...
# 278        Zombie (Simon Garth)  ...  war hero simon garth turn zombi secretari layl...
# 279                       Zuras  ...                                  zura leader etern
# 280                       Zzzax  ...  A chain reaction atom reactor result terrorist...
# 281                        Pepe  ...  pepe leader etern He strong iron small ant He ...
#
# [282 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

bagOfWordsModel = TfidfVectorizer()
bagOfWordsModel.fit(preprocessedData['processed_text'])
textsBoW= bagOfWordsModel.transform(preprocessedData['processed_text'])

# %% [markdown]
# A continuación se crea una matriz N x N (N= número de personajes) en donde el valor de la posición matriz[ i , j ] indique la distancia que existe entre el personaje i y el personaje j.

# %%
from sklearn.metrics import pairwise_distances

distance_matrix= pairwise_distances(textsBoW,textsBoW ,metric='cosine')

# %% [markdown]
# Ahora basta con obtener el índice de la persona introducida y las distancias con el resto de personajes

# %%
indexOfTitle = preprocessedData[preprocessedData['name']==nombre].index.values[0]
indexOfTitle

distance_scores = list(enumerate(distance_matrix[indexOfTitle]))
distance_scores
# Out:
# [(0, 0.9429037594051554),
#  (1, 0.8737492680194615),
#  (2, 1.0),
#  (3, 1.0),
#  (4, 1.0),
#  (5, 0.9566567344748318),
#  (6, 1.0),
#  (7, 1.0),
#  (8, 0.9481970831793141),
#  (9, 1.0),
#  (10, 0.9421206203190599),
#  (11, 1.0),
#  (12, 1.0),
#  (13, 1.0),
#  (14, 1.0),
#  (15, 1.0),
#  (16, 1.0),
#  (17, 1.0),
#  (18, 1.0),
#  (19, 0.8838856415313219),
#  (20, 1.0),
#  (21, 1.0),
#  (22, 1.0),
#  (23, 1.0),
#  (24, 1.0),
#  (25, 1.0),
#  (26, 1.0),
#  (27, 1.0),
#  (28, 1.0),
#  (29, 1.0),
#  (30, 1.0),
#  (31, 1.0),
#  (32, 1.0),
#  (33, 1.0),
#  (34, 1.0),
#  (35, 1.0),
#  (36, 1.0),
#  (37, 1.0),
#  (38, 0.9299958674731036),
#  (39, 1.0),
#  (40, 0.9478446467461085),
#  (41, 0.9549177211043653),
#  (42, 0.9189019686961419),
#  (43, 0.9223008745731874),
#  (44, 1.0),
#  (45, 1.0),
#  (46, 1.0),
#  (47, 0.9511172137781917),
#  (48, 1.0),
#  (49, 1.0),
#  (50, 0.9514025527164229),
#  (51, 1.0),
#  (52, 1.0),
#  (53, 1.0),
#  (54, 1.0),
#  (55, 1.0),
#  (56, 1.0),
#  (57, 0.9497235166279826),
#  (58, 0.9343482964519906),
#  (59, 1.0),
#  (60, 1.0),
#  (61, 1.0),
#  (62, 1.0),
#  (63, 1.0),
#  (64, 1.0),
#  (65, 1.0),
#  (66, 1.0),
#  (67, 1.0),
#  (68, 1.0),
#  (69, 1.0),
#  (70, 0.9261745123469376),
#  (71, 0.9006089724959818),
#  (72, 1.0),
#  (73, 1.0),
#  (74, 1.0),
#  (75, 1.0),
#  (76, 1.0),
#  (77, 1.0),
#  (78, 1.0),
#  (79, 1.0),
#  (80, 1.0),
#  (81, 0.9456947338532178),
#  (82, 1.0),
#  (83, 1.0),
#  (84, 1.0),
#  (85, 1.0),
#  (86, 1.0),
#  (87, 1.0),
#  (88, 1.0),
#  (89, 1.0),
#  (90, 1.0),
#  (91, 1.0),
#  (92, 1.0),
#  (93, 1.0),
#  (94, 1.0),
#  (95, 1.0),
#  (96, 1.0),
#  (97, 1.0),
#  (98, 1.0),
#  (99, 1.0),
#  (100, 1.0),
#  (101, 0.9411151438454797),
#  (102, 1.0),
#  (103, 1.0),
#  (104, 1.0),
#  (105, 1.0),
#  (106, 1.0),
#  (107, 1.0),
#  (108, 1.0),
#  (109, 1.0),
#  (110, 1.0),
#  (111, 1.0),
#  (112, 1.0),
#  (113, 1.0),
#  (114, 1.0),
#  (115, 1.0),
#  (116, 1.0),
#  (117, 1.0),
#  (118, 1.0),
#  (119, 1.0),
#  (120, 1.0),
#  (121, 1.0),
#  (122, 0.9534922697984229),
#  (123, 1.0),
#  (124, 1.0),
#  (125, 1.0),
#  (126, 0.9089324712744773),
#  (127, 1.0),
#  (128, 1.0),
#  (129, 1.0),
#  (130, 1.0),
#  (131, 1.0),
#  (132, 1.0),
#  (133, 1.0),
#  (134, 1.0),
#  (135, 1.0),
#  (136, 0.9529566705122121),
#  (137, 1.0),
#  (138, 1.0),
#  (139, 1.0),
#  (140, 0.9353501019861358),
#  (141, 1.0),
#  (142, 1.0),
#  (143, 1.0),
#  (144, 1.0),
#  (145, 1.0),
#  (146, 1.0),
#  (147, 1.0),
#  (148, 1.0),
#  (149, 1.0),
#  (150, 1.0),
#  (151, 1.0),
#  (152, 1.0),
#  (153, 0.9434001866332543),
#  (154, 1.0),
#  (155, 1.0),
#  (156, 1.0),
#  (157, 1.0),
#  (158, 1.0),
#  (159, 1.0),
#  (160, 1.0),
#  (161, 1.0),
#  (162, 1.0),
#  (163, 1.0),
#  (164, 1.0),
#  (165, 1.0),
#  (166, 1.0),
#  (167, 1.0),
#  (168, 1.0),
#  (169, 1.0),
#  (170, 0.8481911415562455),
#  (171, 0.8000775160378006),
#  (172, 1.0),
#  (173, 1.0),
#  (174, 0.927804124283846),
#  (175, 1.0),
#  (176, 0.8685070563769115),
#  (177, 0.9208233862525436),
#  (178, 1.0),
#  (179, 1.0),
#  (180, 0.9311798620576808),
#  (181, 1.0),
#  (182, 1.0),
#  (183, 1.0),
#  (184, 1.0),
#  (185, 1.0),
#  (186, 1.0),
#  (187, 1.0),
#  (188, 1.0),
#  (189, 1.0),
#  (190, 1.0),
#  (191, 1.0),
#  (192, 1.0),
#  (193, 1.0),
#  (194, 1.0),
#  (195, 1.0),
#  (196, 1.0),
#  (197, 1.0),
#  (198, 1.0),
#  (199, 1.0),
#  (200, 1.0),
#  (201, 1.0),
#  (202, 1.0),
#  (203, 1.0),
#  (204, 1.0),
#  (205, 1.0),
#  (206, 1.0),
#  (207, 1.0),
#  (208, 1.0),
#  (209, 1.0),
#  (210, 1.0),
#  (211, 0.9573268303684124),
#  (212, 1.0),
#  (213, 1.0),
#  (214, 1.0),
#  (215, 1.0),
#  (216, 0.929035759891847),
#  (217, 1.0),
#  (218, 1.0),
#  (219, 1.0),
#  (220, 0.9380952999448944),
#  (221, 1.0),
#  (222, 1.0),
#  (223, 1.0),
#  (224, 1.0),
#  (225, 1.0),
#  (226, 1.0),
#  (227, 1.0),
#  (228, 1.0),
#  (229, 1.0),
#  (230, 1.0),
#  (231, 1.0),
#  (232, 1.0),
#  (233, 1.0),
#  (234, 1.0),
#  (235, 1.0),
#  (236, 1.0),
#  (237, 1.0),
#  (238, 1.0),
#  (239, 1.0),
#  (240, 1.0),
#  (241, 1.0),
#  (242, 1.0),
#  (243, 1.0),
#  (244, 1.0),
#  (245, 1.0),
#  (246, 1.0),
#  (247, 1.0),
#  (248, 1.0),
#  (249, 1.0),
#  (250, 1.0),
#  (251, 1.0),
#  (252, 1.0),
#  (253, 0.9680501546723466),
#  (254, 1.0),
#  (255, 1.0),
#  (256, 1.0),
#  (257, 1.0),
#  (258, 1.0),
#  (259, 1.0),
#  (260, 1.0),
#  (261, 1.0),
#  (262, 1.0),
#  (263, 1.0),
#  (264, 1.0),
#  (265, 1.0),
#  (266, 1.0),
#  (267, 1.0),
#  (268, 1.0),
#  (269, 1.0),
#  (270, 1.0),
#  (271, 1.0),
#  (272, 0.9420145462520628),
#  (273, 1.0),
#  (274, 1.0),
#  (275, 1.0),
#  (276, 1.0),
#  (277, 1.0),
#  (278, 1.0),
#  (279, 0.720027498092748),
#  (280, 0.9351049394360071),
#  (281, 0.0)]

# %% [markdown]
# Una vez tenemos las distancias, únicamente debemos ordenarlas, quedarnos con las más cortas y mostrarlas de forma legible.

# %%
ordered_scores = sorted(distance_scores, key=lambda x: x[1])
top_scores = ordered_scores[1:11]
top_indexes = [i[0] for i in top_scores]
preprocessedData['name'].iloc[top_indexes]
# Out:
# 279                                 Zuras
# 171                                 Thena
# 170                      The Leader (HAS)
# 176                            Thor (MAA)
# 1                                  A.I.M.
# 19     Captain America/Steve Rogers (MAA)
# 71                            Shadow King
# 126                                Sprite
# 42              Iron Man/Tony Stark (MAA)
# 177                       Thor (Ultimate)
# Name: name, dtype: object

# %% [markdown]
# ##**2.2 Basado en su descripción y parámetros adicionales**

# %% [markdown]
# **Búsqueda basada en Descripción + Valoración Comentarios + Valoración Directa (Likes) + Valoración Media Comentarios**
#
# Ponderación:
#
# * Descripción (70%): se basa en el parecido entre la descripción que tenga el usuario y la descripción de cada personaje
# * Valoración Comentarios (7.5%): se basa en la valoración del comentario textual que realice el usuario a un personaje. Estos valores son extraídos del subsistema de valoración. Puede ser:
#   * Buena (0)
#   * Neutra o no valoración (0.5)
#   * Mala (1)
# * Valoración Directa por Likes (15%)
#   * Like (0)
#   * Dislike (1)
#   * Nnguna (0.5)
# * Valoración Media Comentarios (7.5%): se trata de la media de las valoraciones de comentarios de todos los usuarios sobre un personaje. Puede ser un valor entre 0 y 1.

# %% [markdown]
# Para probar esta parte del sistema simularemos tener los datos de las valoraciones de los comentarios y las valoraciones directas.
#
# A continuación se generan aleatoriamente las valoraciones:
#
# * 0  es valoración positiva
# * 0.5 es valoración neutra (o no valoración)
# * 1 es valoración negativa

# %%
from random import choice, randint

valoracion_comentario = []
valoracion_directa = []
valoracion_media = []

for i in range(0,len(preprocessedData)):
  valoracion_comentario.append(choice([0.0, 0.5, 1.0]))
  valoracion_directa.append(choice([0.0, 0.5, 1.0]))
  valoracion_media.append(randint(0.0,100.0)/100.0)

preprocessedData['valoracion_comentario'] = valoracion_comentario
preprocessedData['valoracion_directa'] = valoracion_directa
preprocessedData['valoracion_media'] = valoracion_media

preprocessedData
# Out:
#                            name  ... valoracion_media
# 0                  A-Bomb (HAS)  ...             0.72
# 1                        A.I.M.  ...             0.39
# 2    Abomination (Emil Blonsky)  ...             0.60
# 3                  Adam Warlock  ...             0.92
# 4                Agent X (Nijo)  ...             0.35
# ..                          ...  ...              ...
# 277                      Zodiak  ...             0.75
# 278        Zombie (Simon Garth)  ...             0.89
# 279                       Zuras  ...             0.85
# 280                       Zzzax  ...             0.47
# 281                        Pepe  ...             0.57
#
# [282 rows x 6 columns]

# %% [markdown]
# A continuación calculamos las distancias teniendo en cuenta la ponderación

# %%
distance_scores_final = []

for i in range(len(distance_matrix[indexOfTitle])):
  valoracion = distance_matrix[indexOfTitle][i]*0.7 + preprocessedData['valoracion_comentario'][i]*0.075 + preprocessedData['valoracion_directa'][i]*0.15 + preprocessedData['valoracion_media'][i]*0.075
  distance_scores_final.append((i,valoracion))

distance_scores_final
# Out:
# [(0, 0.7140326315836087),
#  (1, 0.865874487613623),
#  (2, 0.82),
#  (3, 0.994),
#  (4, 0.8387499999999999),
#  (5, 0.8106597141323821),
#  (6, 0.8634999999999999),
#  (7, 0.8019999999999999),
#  (8, 0.6772379582255198),
#  (9, 0.91825),
#  (10, 0.7727344342233419),
#  (11, 0.7555),
#  (12, 0.78475),
#  (13, 0.8177499999999999),
#  (14, 0.82),
#  (15, 0.76225),
#  (16, 0.8815),
#  (17, 0.9415),
#  (18, 0.7697499999999999),
#  (19, 0.7432199490719252),
#  (20, 0.91525),
#  (21, 0.9085),
#  (22, 0.8034999999999999),
#  (23, 0.92575),
#  (24, 0.90775),
#  (25, 0.8769999999999999),
#  (26, 0.79375),
#  (27, 0.8927499999999999),
#  (28, 0.8642499999999999),
#  (29, 0.8965),
#  (30, 0.74725),
#  (31, 0.736),
#  (32, 0.8282499999999999),
#  (33, 0.9039999999999999),
#  (34, 0.90925),
#  (35, 0.89725),
#  (36, 0.7749999999999999),
#  (37, 0.8717499999999999),
#  (38, 0.8084971072311724),
#  (39, 0.727),
#  (40, 0.7092412527222759),
#  (41, 0.9384424047730557),
#  (42, 0.8577313780872993),
#  (43, 0.7206106122012311),
#  (44, 0.8447499999999999),
#  (45, 0.7749999999999999),
#  (46, 0.9099999999999999),
#  (47, 0.6867820496447342),
#  (48, 0.8237499999999999),
#  (49, 0.90325),
#  (50, 0.6907317869014961),
#  (51, 0.79675),
#  (52, 0.8387499999999999),
#  (53, 0.8304999999999999),
#  (54, 0.817),
#  (55, 0.9182499999999999),
#  (56, 0.99325),
#  (57, 0.6933064616395878),
#  (58, 0.8400438075163934),
#  (59, 0.91075),
#  (60, 0.8402499999999999),
#  (61, 0.8372499999999999),
#  (62, 0.8184999999999999),
#  (63, 0.99325),
#  (64, 0.87925),
#  (65, 0.8454999999999999),
#  (66, 0.8867499999999999),
#  (67, 0.85825),
#  (68, 0.8679999999999999),
#  (69, 0.77125),
#  (70, 0.8253221586428562),
#  (71, 0.7714262807471872),
#  (72, 0.78475),
#  (73, 0.8102499999999999),
#  (74, 0.74725),
#  (75, 0.7667499999999999),
#  (76, 0.8207499999999999),
#  (77, 0.8679999999999999),
#  (78, 0.85825),
#  (79, 0.9504999999999999),
#  (80, 0.8282499999999999),
#  (81, 0.8562363136972524),
#  (82, 0.7952499999999999),
#  (83, 0.9099999999999999),
#  (84, 0.8949999999999999),
#  (85, 0.90025),
#  (86, 0.8154999999999999),
#  (87, 0.7795),
#  (88, 0.7517499999999999),
#  (89, 0.9219999999999999),
#  (90, 0.883),
#  (91, 0.7667499999999999),
#  (92, 0.8252499999999999),
#  (93, 0.826),
#  (94, 0.8972499999999999),
#  (95, 0.8057499999999999),
#  (96, 0.982),
#  (97, 0.7974999999999999),
#  (98, 0.8732499999999999),
#  (99, 0.8222499999999999),
#  (100, 0.8057499999999999),
#  (101, 0.9400306006918357),
#  (102, 0.8507499999999999),
#  (103, 0.7869999999999999),
#  (104, 0.8634999999999999),
#  (105, 0.7599999999999999),
#  (106, 0.8207499999999999),
#  (107, 0.7397499999999999),
#  (108, 0.949),
#  (109, 0.9017499999999998),
#  (110, 0.9265),
#  (111, 0.9242499999999999),
#  (112, 0.9999999999999999),
#  (113, 0.86125),
#  (114, 0.97525),
#  (115, 0.91975),
#  (116, 0.75925),
#  (117, 0.9309999999999999),
#  (118, 0.76),
#  (119, 0.9145),
#  (120, 0.7314999999999999),
#  (121, 0.826),
#  (122, 0.8519445888588959),
#  (123, 0.84625),
#  (124, 0.9564999999999999),
#  (125, 0.8724999999999999),
#  (126, 0.774252729892134),
#  (127, 0.9279999999999999),
#  (128, 0.89725),
#  (129, 0.7615),
#  (130, 0.823),
#  (131, 0.8439999999999999),
#  (132, 0.8162499999999999),
#  (133, 0.7765),
#  (134, 0.7982499999999999),
#  (135, 0.8529999999999999),
#  (136, 0.7803196693585484),
#  (137, 0.8694999999999998),
#  (138, 0.8454999999999999),
#  (139, 0.8079999999999999),
#  (140, 0.6877450713902951),
#  (141, 0.91525),
#  (142, 0.78475),
#  (143, 0.8387499999999999),
#  (144, 0.8964999999999999),
#  (145, 0.7952499999999999),
#  (146, 0.9684999999999999),
#  (147, 0.8342499999999999),
#  (148, 0.7832499999999999),
#  (149, 0.8469999999999999),
#  (150, 0.8897499999999999),
#  (151, 0.9249999999999999),
#  (152, 0.8874999999999998),
#  (153, 0.7616301306432779),
#  (154, 0.8987499999999998),
#  (155, 0.9977499999999999),
#  (156, 0.9024999999999999),
#  (157, 0.92575),
#  (158, 0.823),
#  (159, 0.7779999999999999),
#  (160, 0.7397499999999999),
#  (161, 0.8574999999999999),
#  (162, 0.9354999999999999),
#  (163, 0.8282499999999999),
#  (164, 0.79375),
#  (165, 0.91675),
#  (166, 0.7839999999999999),
#  (167, 0.88825),
#  (168, 0.7884999999999999),
#  (169, 0.87475),
#  (170, 0.8179837990893718),
#  (171, 0.7550542612264604),
#  (172, 0.9175),
#  (173, 0.96175),
#  (174, 0.7919628869986921),
#  (175, 0.8589999999999999),
#  (176, 0.695704939463838),
#  (177, 0.7360763703767805),
#  (178, 0.8402499999999999),
#  (179, 0.9145),
#  (180, 0.8258259034403764),
#  (181, 0.8124999999999999),
#  (182, 0.8147499999999999),
#  (183, 0.8094999999999999),
#  (184, 0.8484999999999999),
#  (185, 0.8372499999999999),
#  (186, 0.751),
#  (187, 0.823),
#  (188, 0.7074999999999999),
#  (189, 0.84925),
#  (190, 0.78775),
#  (191, 0.8304999999999999),
#  (192, 0.9385),
#  (193, 0.80275),
#  (194, 0.8447499999999999),
#  (195, 0.748),
#  (196, 0.71575),
#  (197, 0.889),
#  (198, 0.8124999999999999),
#  (199, 0.7555),
#  (200, 0.7022499999999999),
#  (201, 0.8042499999999999),
#  (202, 0.94075),
#  (203, 0.9017499999999999),
#  (204, 0.8012499999999999),
#  (205, 0.7705),
#  (206, 0.8829999999999999),
#  (207, 0.8987499999999999),
#  (208, 0.9535),
#  (209, 0.7397499999999999),
#  (210, 0.9482499999999999),
#  (211, 0.8906287812578887),
#  (212, 0.8124999999999999),
#  (213, 0.7832499999999999),
#  (214, 0.841),
#  (215, 0.8447499999999999),
#  (216, 0.8708250319242928),
#  (217, 0.8267499999999999),
#  (218, 0.9512499999999999),
#  (219, 0.96925),
#  (220, 0.787166709961426),
#  (221, 0.9594999999999999),
#  (222, 0.817),
#  (223, 0.9947499999999999),
#  (224, 0.7142499999999999),
#  (225, 0.8282499999999999),
#  (226, 0.9294999999999999),
#  (227, 0.8867499999999998),
#  (228, 0.8087499999999999),
#  (229, 0.8724999999999998),
#  (230, 0.8222499999999999),
#  (231, 0.77125),
#  (232, 0.79375),
#  (233, 0.8867499999999998),
#  (234, 0.9219999999999999),
#  (235, 0.9602499999999999),
#  (236, 0.7959999999999999),
#  (237, 0.9617499999999999),
#  (238, 0.8762499999999999),
#  (239, 0.8064999999999999),
#  (240, 0.9024999999999999),
#  (241, 0.94),
#  (242, 0.8574999999999999),
#  (243, 0.8597499999999999),
#  (244, 0.7727499999999999),
#  (245, 0.8274999999999999),
#  (246, 0.8649999999999999),
#  (247, 0.9849999999999999),
#  (248, 0.8837499999999998),
#  (249, 0.75025),
#  (250, 0.748),
#  (251, 0.8687499999999999),
#  (252, 0.8402499999999999),
#  (253, 0.7961351082706425),
#  (254, 0.8919999999999999),
#  (255, 0.9069999999999999),
#  (256, 0.85075),
#  (257, 0.9887499999999999),
#  (258, 0.8394999999999999),
#  (259, 0.9047499999999998),
#  (260, 0.8537499999999999),
#  (261, 0.703),
#  (262, 0.9452499999999999),
#  (263, 0.8417499999999999),
#  (264, 0.78775),
#  (265, 0.7254999999999999),
#  (266, 0.72925),
#  (267, 0.8364999999999999),
#  (268, 0.9099999999999999),
#  (269, 0.7945),
#  (270, 0.8769999999999999),
#  (271, 0.736),
#  (272, 0.8881601823764439),
#  (273, 0.9857499999999999),
#  (274, 0.9482499999999999),
#  (275, 0.76525),
#  (276, 0.8042499999999999),
#  (277, 0.8312499999999999),
#  (278, 0.9542499999999999),
#  (279, 0.7177692486649234),
#  (280, 0.7648234576052049),
#  (281, 0.08024999999999999)]

# %% [markdown]
# A continuación nos quedamos con los personajes más aprecidos

# %%
ordered_scores_final = sorted(distance_scores_final, key=lambda x: x[1])
top_scores_final = ordered_scores_final[1:11]
top_indexes_final = [i[0] for i in top_scores_final]
preprocessedData['name'].iloc[top_indexes_final]
# Out:
# 8                       Avengers
# 47                Mariko Yashida
# 140    Storm (Age of Apocalypse)
# 50             Matsu'o Tsurayaba
# 57               Power Man (USM)
# 176                   Thor (MAA)
# 200                   U.S. Agent
# 261                     Wolf Cub
# 188                    Tippy Toe
# 40               Iron Fist (USM)
# Name: name, dtype: object

# %% [markdown]
# #**3. Resumen de los resultados**

# %% [markdown]
# **Resultados del punto 2.1**: se muestran a continuación las descripciones para comprobar que existe algún parecido

# %%
descripcion
# Out:
# 'Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist'

# %%
preprocessedData['name'].iloc[top_indexes]
# Out:
# 279                                 Zuras
# 171                                 Thena
# 170                      The Leader (HAS)
# 176                            Thor (MAA)
# 1                                  A.I.M.
# 19     Captain America/Steve Rogers (MAA)
# 71                            Shadow King
# 126                                Sprite
# 42              Iron Man/Tony Stark (MAA)
# 177                       Thor (Ultimate)
# Name: name, dtype: object

# %%
preprocessedData['description'].iloc[top_indexes]
# Out:
# 279           Zuras was once the leader of the Eternals.
# 171    Thena, a second generation Eternal, is the eld...
# 170    What the Hulk has in strength, the Leader has ...
# 176    Thor is the Asgardian Prince of Thunder, the s...
# 1      AIM is a terrorist organization bent on destro...
# 19     During World War II, Steve Rogers enlisted in ...
# 71     One of the oldest and more powerful mutants ev...
# 126    Sprite is a mischievous Eternal who maintains ...
# 42     Tony Stark is the genius inventor/billionaire/...
# 177    He claims he is the legendary Norse thunder de...
# Name: description, dtype: object

# %% [markdown]
# **Resultados del punto 2.1**: se muestran a continuación las descripciones para comprobar que existe algún parecido (se debe tener en este caso la descripción no tiene todo el peso del cálculo)

# %%
descripcion
# Out:
# 'Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist'

# %%
preprocessedData['name'].iloc[top_indexes_final]
# Out:
# 8                       Avengers
# 47                Mariko Yashida
# 140    Storm (Age of Apocalypse)
# 50             Matsu'o Tsurayaba
# 57               Power Man (USM)
# 176                   Thor (MAA)
# 200                   U.S. Agent
# 261                     Wolf Cub
# 188                    Tippy Toe
# 40               Iron Fist (USM)
# Name: name, dtype: object

# %%
preprocessedData['description'].iloc[top_indexes_final]
# Out:
# 8      Earth's Mightiest Heroes joined forces to take...
# 47     Mariko Yashida was the daughter of Japanese cr...
# 140    Calling herself the Windrider, Storm carved ou...
# 50     Tsurayaba became leader of a faction of the ni...
# 57     A former street kid whoâ€™s not quite used to ...
# 176    Thor is the Asgardian Prince of Thunder, the s...
# 200    With the end of the Vietnam War, John Walker t...
# 261    Nicholas Gleason enrolled at the Xavier Instit...
# 188    After the senseless murder of Squirrel Girl’s ...
# 40     Danny is always focused yet relaxed - more Zen...
# Name: description, dtype: object
