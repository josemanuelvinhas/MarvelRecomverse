# %% [markdown]
# <a href="https://colab.research.google.com/github/josemanuelvinhas/MarvelRecomverse/blob/main/MarvelRecomverse_Sistema_de_Recomendaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**0. Sistema de Recomendación**

# %% [markdown]
# En este Notebook se realiza la implementación del sistema de recomendación de la aplicación.
#
# En el primer punto se calcula la matriz de parecidos entre todos los personajes del dataset. Se realiza a modo de prueba, ya que no es necesario para la aplicación.
#
# En el segundo punto se buscan los personajes más similares a una persona en función de dos criterios distintos:
# * Descripción
# * Descripción + Valoración Comentarios + Valoración Directa (Likes) + Valoración Media Comentarios
#
# El uso de distintos criterios se realiza únicamente para comprobar como afectan al resultado final.
#
# *NOTA: el dataset que se empleará está disponible [aquí](https://github.com/josemanuelvinhas/MarvelRecomverse/blob/main/marvel.csv)*

# %% [markdown]
# #**1. Cálculo de la matriz de parecidos**

# %% [markdown]
# ##**1.1 Preprocesado del dataset**

# %% [markdown]
# Para poder trabajar con los datos se deberá realizar un preprocesado de las descripciones.
#
# El dataset con el que se trabaja contiene una colección de 281 personajes. Cada uno tiene dos campos:
#
# 1.   *name*: nombre del personaje
# 2.   *description*: descripcion del personaje
#
# Se hará uso de la librería *pandas* para el preprocesado. A continuación se carga el csv con los datos

# %%
import pandas as pd

originalData = pd.read_csv('marvel.csv')
originalData
# Out:
#                            name                                        description
# 0                  A-Bomb (HAS)  Rick Jones has been Hulk's best bud since day ...
# 1                        A.I.M.  AIM is a terrorist organization bent on destro...
# 2    Abomination (Emil Blonsky)  Formerly known as Emil Blonsky, a spy of Sovie...
# 3                  Adam Warlock  Adam Warlock is an artificially created human ...
# 4                Agent X (Nijo)  Originally a partner of the mind-altering assa...
# ..                          ...                                                ...
# 276                       Zarek  Zarek is a member of the Kree race with no sup...
# 277                      Zodiak  Twelve demons merged with Norman Harrison, who...
# 278        Zombie (Simon Garth)  War hero Simon Garth was turned into a zombie ...
# 279                       Zuras         Zuras was once the leader of the Eternals.
# 280                       Zzzax  A chain reaction in an atomic reactor, a resul...
#
# [281 rows x 2 columns]

# %% [markdown]
# A continuación se llevará a cabo el preprocesado, en la que se usarán 3 técnicas:
#
# 1.   ***Tokenization***: división del texto en palabras
# 2.   Eliminación de ***stopwords***
# 3. ***Stemmization***: permite la obtención de la raíz de cada palabra sin que el resultado sea una palabra real.

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
nltk.download('punkt')
nltk.download('stopwords')

ps = PorterStemmer()

preprocessedText = []

for row in originalData.itertuples():
    text = word_tokenize(row[2]) ## indice de la columna que contiene la descripcion
    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [ps.stem(w) for w in text if not w in stops and w.isalnum()]
    text = " ".join(text)
    
    preprocessedText.append(text)

preprocessedData = originalData
preprocessedData['processed_text'] = preprocessedText

preprocessedData
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                            name  ...                                     processed_text
# 0                  A-Bomb (HAS)  ...  rick jone hulk best bud sinc day one friend te...
# 1                        A.I.M.  ...             aim terrorist organ bent destroy world
# 2    Abomination (Emil Blonsky)  ...  formerli known emil blonski spi soviet yugosla...
# 3                  Adam Warlock  ...  adam warlock artifici creat human born cocoon ...
# 4                Agent X (Nijo)  ...  origin partner assassin black swan nijo spi de...
# ..                          ...  ...                                                ...
# 276                       Zarek  ...  zarek member kree race superhuman abil special...
# 277                      Zodiak  ...  twelv demon merg norman harrison soon adopt gu...
# 278        Zombie (Simon Garth)  ...  war hero simon garth turn zombi secretari layl...
# 279                       Zuras  ...                                  zura leader etern
# 280                       Zzzax  ...  A chain reaction atom reactor result terrorist...
#
# [281 rows x 3 columns]

# %% [markdown]
# ##**1.2 Creación de la bolsa de palabras (BoW) con TF-IDF**

# %% [markdown]
# Se parte de los datos almacenados en "preprocessedData", en donde para cada personaje existe un campo 'preprocessed_text' que contiene la descripción preprocesada.
#
# El objetivo es transformar todos los textos de sinopsis en vectores de frecuencias (Bag of words), aplicando además la ponderación TF-IDF para los valores de dichas frecuencias.
#
# El paquete sklearn ofrece una clase llamada *TfidfVectorizer* que crea automáticamente la matriz compuesta por todos los vectores de frecuencias ponderados a partir de un array de textos (preprocessedData['processed_text'])
#
# Si se quiere emplear la bolsa de palabras sin ponderación TF-IDF puede usarse la clase *CountVectorized* del mismo paquete

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

bagOfWordsModel = TfidfVectorizer()
bagOfWordsModel.fit(preprocessedData['processed_text'])
textsBoW= bagOfWordsModel.transform(preprocessedData['processed_text'])
print("Finished")
# Out:
# Finished

# %%
textsBoW.shape
# Out:
# (281, 2283)

# %%
print(textsBoW)
# Out:
#   (0, 2137)	0.130889104582123
#   (0, 2058)	0.14217279372193212
#   (0, 2004)	0.22205823661448335
#   (0, 1974)	0.22205823661448335
#   (0, 1894)	0.1961840975559547
#   (0, 1790)	0.1961840975559547
#   (0, 1779)	0.1752944840330487
#   (0, 1634)	0.22205823661448335
#   (0, 1505)	0.10190245579244313
#   (0, 1404)	0.11629865466340347
#   (0, 1174)	0.16198034620346324
#   (0, 1086)	0.22205823661448335
#   (0, 968)	0.1468449451157794
#   (0, 840)	0.20692283552679946
#   (0, 816)	0.17030995849742606
#   (0, 797)	0.14942034497452006
#   (0, 695)	0.1752944840330487
#   (0, 647)	0.16198034620346324
#   (0, 537)	0.1878544852619919
#   (0, 496)	0.1878544852619919
#   (0, 475)	0.22205823661448335
#   (0, 284)	0.20692283552679946
#   (0, 251)	0.22205823661448335
#   (0, 242)	0.1878544852619919
#   (0, 214)	0.1752944840330487
#   :	:
#   (278, 818)	0.30506443106319997
#   (278, 81)	0.2225292018497309
#   (279, 2282)	0.6554139206650713
#   (279, 1148)	0.49150479114816825
#   (279, 669)	0.5734593559066198
#   (280, 1993)	0.22286926032113236
#   (280, 1726)	0.25226282639126546
#   (280, 1662)	0.25226282639126546
#   (280, 1623)	0.2134066455942286
#   (280, 1577)	0.25226282639126546
#   (280, 1576)	0.25226282639126546
#   (280, 1346)	0.23506869247776788
#   (280, 970)	0.159087426424004
#   (280, 868)	0.19913822007758497
#   (280, 775)	0.16974465400745184
#   (280, 695)	0.19913822007758497
#   (280, 647)	0.18401307952409543
#   (280, 620)	0.25226282639126546
#   (280, 456)	0.16408212818086607
#   (280, 340)	0.25226282639126546
#   (280, 255)	0.22286926032113236
#   (280, 158)	0.25226282639126546
#   (280, 157)	0.23506869247776788
#   (280, 22)	0.22286926032113236
#   (280, 17)	0.23506869247776788

# %%
bagOfWordsModel.get_feature_names()
# Out:
# ['13',
#  '1910',
#  '1930',
#  '1931',
#  '1940',
#  '19th',
#  '21st',
#  '31st',
#  '53rd',
#  '60',
#  'abandon',
#  'abduct',
#  'abil',
#  'abl',
#  'abomin',
#  'abraham',
#  'abruptli',
#  'absorb',
#  'abus',
#  'academ',
#  'acceler',
#  'access',
#  'accident',
#  'accomplish',
#  'accord',
#  'account',
#  'accustom',
#  'acolyt',
#  'acquir',
#  'acrobat',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'actress',
#  'ad',
#  'adam',
#  'adamantium',
#  'adapt',
#  'add',
#  'admiss',
#  'adolesc',
#  'adopt',
#  'adrian',
#  'adulthood',
#  'advanc',
#  'advantag',
#  'adventur',
#  'aegi',
#  'affect',
#  'affin',
#  'affluent',
#  'africa',
#  'african',
#  'after',
#  'age',
#  'agenc',
#  'agent',
#  'ago',
#  'agre',
#  'aid',
#  'aim',
#  'air',
#  'airdrop',
#  'albeit',
#  'alberta',
#  'alex',
#  'alexand',
#  'alia',
#  'alien',
#  'alik',
#  'all',
#  'allegi',
#  'alli',
#  'allow',
#  'almost',
#  'alon',
#  'along',
#  'alongsid',
#  'alpha',
#  'alreadi',
#  'also',
#  'alter',
#  'altern',
#  'although',
#  'alvarez',
#  'alway',
#  'amahl',
#  'amaz',
#  'america',
#  'american',
#  'among',
#  'amora',
#  'amount',
#  'amphibi',
#  'amulet',
#  'amun',
#  'an',
#  'anathema',
#  'ancient',
#  'and',
#  'andrea',
#  'android',
#  'andromeda',
#  'andsew',
#  'angela',
#  'angelo',
#  'anger',
#  'angrier',
#  'anim',
#  'anoth',
#  'anton',
#  'anyon',
#  'anyth',
#  'apart',
#  'apocalyps',
#  'appar',
#  'appear',
#  'appetit',
#  'appoint',
#  'apprehend',
#  'approach',
#  'aralun',
#  'araña',
#  'arch',
#  'archer',
#  'area',
#  'arguabl',
#  'arliss',
#  'arm',
#  'armi',
#  'armor',
#  'arnim',
#  'aros',
#  'around',
#  'arrow',
#  'art',
#  'artifici',
#  'artist',
#  'as',
#  'asgard',
#  'asgardian',
#  'ashida',
#  'asia',
#  'ask',
#  'aspect',
#  'assassin',
#  'asset',
#  'assign',
#  'assist',
#  'associ',
#  'assum',
#  'astrolog',
#  'ate',
#  'athlet',
#  'atla',
#  'atlanti',
#  'atom',
#  'attack',
#  'attempt',
#  'attitud',
#  'aunt',
#  'australia',
#  'australian',
#  'author',
#  'ava',
#  'aveng',
#  'averag',
#  'await',
#  'awar',
#  'award',
#  'away',
#  'awesom',
#  'ayala',
#  'azazel',
#  'back',
#  'backbon',
#  'badilino',
#  'badli',
#  'balanc',
#  'ball',
#  'band',
#  'bank',
#  'banner',
#  'banshe',
#  'baron',
#  'barton',
#  'base',
#  'basi',
#  'battl',
#  'battlefield',
#  'be',
#  'beacher',
#  'beast',
#  'beat',
#  'becam',
#  'becom',
#  'beehiv',
#  'beemont',
#  'beetl',
#  'beg',
#  'began',
#  'begin',
#  'behalf',
#  'behav',
#  'behavior',
#  'behemoth',
#  'behest',
#  'believ',
#  'belong',
#  'belt',
#  'ben',
#  'benjamin',
#  'bent',
#  'best',
#  'beta',
#  'betray',
#  'better',
#  'biblic',
#  'big',
#  'bigger',
#  'biggest',
#  'billi',
#  'billion',
#  'billionair',
#  'biochemist',
#  'bird',
#  'birj',
#  'birth',
#  'bishop',
#  'bison',
#  'bit',
#  'bite',
#  'bitten',
#  'black',
#  'blackfoot',
#  'blacki',
#  'blast',
#  'bless',
#  'blind',
#  'blonski',
#  'blood',
#  'blue',
#  'bob',
#  'bodi',
#  'bomb',
#  'bond',
#  'border',
#  'born',
#  'bounti',
#  'bourn',
#  'bowl',
#  'boxer',
#  'boy',
#  'brag',
#  'brain',
#  'brainwash',
#  'brave',
#  'brazilian',
#  'breach',
#  'breadth',
#  'break',
#  'breakdown',
#  'breath',
#  'brethren',
#  'brian',
#  'bright',
#  'brilliant',
#  'britain',
#  'british',
#  'broadcast',
#  'brock',
#  'broker',
#  'brood',
#  'brooklyn',
#  'brother',
#  'brotherhood',
#  'brought',
#  'bruce',
#  'bruiser',
#  'brunnhild',
#  'brutal',
#  'brutish',
#  'bu',
#  'bud',
#  'bugl',
#  'build',
#  'built',
#  'bulldoz',
#  'bulli',
#  'burp',
#  'burst',
#  'but',
#  'buzzard',
#  'by',
#  'ca',
#  'cabal',
#  'cabin',
#  'cabl',
#  'calcuttan',
#  'caldwel',
#  'calgari',
#  'call',
#  'cambodia',
#  'came',
#  'cameron',
#  'camp',
#  'canada',
#  'canadian',
#  'canaver',
#  'candid',
#  'cannon',
#  'cape',
#  'capit',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'card',
#  'career',
#  'cargo',
#  'carmella',
#  'carmilla',
#  'carnag',
#  'carniv',
#  'carol',
#  'carson',
#  'cartoon',
#  'carv',
#  'cassi',
#  'cassidi',
#  'cast',
#  'caught',
#  'caus',
#  'celebr',
#  'celesti',
#  'cell',
#  'cellmat',
#  'centuri',
#  'certainli',
#  'chain',
#  'challeng',
#  'chamber',
#  'champion',
#  'chan',
#  'chanc',
#  'chang',
#  'channel',
#  'chao',
#  'chapman',
#  'charact',
#  'charg',
#  'chariti',
#  'charl',
#  'chase',
#  'chast',
#  'chemic',
#  'chemist',
#  'chief',
#  'child',
#  'childhood',
#  'children',
#  'chill',
#  'chin',
#  'choic',
#  'choos',
#  'chord',
#  'chosen',
#  'chri',
#  'christoph',
#  'church',
#  'circl',
#  'circuitri',
#  'citi',
#  'civil',
#  'civilian',
#  'claim',
#  'clan',
#  'clandestin',
#  'clash',
#  'class',
#  'claw',
#  'clint',
#  'cloak',
#  'clone',
#  'close',
#  'club',
#  'clutch',
#  'coat',
#  'cocoon',
#  'codenam',
#  'cold',
#  'colleen',
#  'colleg',
#  'collin',
#  'combat',
#  'combin',
#  'come',
#  'command',
#  'comment',
#  'commiss',
#  'commit',
#  'commun',
#  'compani',
#  'compassion',
#  'compet',
#  'competit',
#  'complex',
#  'composit',
#  'compound',
#  'comput',
#  'concept',
#  'concuss',
#  'conduct',
#  'confront',
#  'connect',
#  'conquest',
#  'conscious',
#  'consid',
#  'conson',
#  'constant',
#  'constantli',
#  'construct',
#  'consum',
#  'contact',
#  'contain',
#  'contempt',
#  'contest',
#  'continu',
#  'control',
#  'controversi',
#  'convers',
#  'convinc',
#  'copi',
#  'core',
#  'corner',
#  'corpor',
#  'corrupt',
#  'cosmic',
#  'cosmo',
#  'cost',
#  'costa',
#  'costum',
#  'could',
#  'coulson',
#  'countless',
#  'countri',
#  'courag',
#  'cousin',
#  'covert',
#  'cowardli',
#  'craft',
#  'craig',
#  'cranki',
#  'crash',
#  'crazi',
#  'creat',
#  'creation',
#  'creatur',
#  'credit',
#  'crew',
#  'cri',
#  'crime',
#  'crimelord',
#  'crimin',
#  'crimson',
#  'crisi',
#  'crowbar',
#  'crystal',
#  'crème',
#  'cube',
#  'cuckoo',
#  'cull',
#  'cult',
#  'cure',
#  'curl',
#  'current',
#  'curs',
#  'custom',
#  'cybel',
#  'cybernet',
#  'cyclop',
#  'da',
#  'dad',
#  'dagger',
#  'daili',
#  'dancer',
#  'danni',
#  'danver',
#  'dare',
#  'daredevil',
#  'darkhawk',
#  'darnel',
#  'daughter',
#  'davi',
#  'david',
#  'day',
#  'db',
#  'de',
#  'dead',
#  'deadli',
#  'deadpool',
#  'deal',
#  'dealer',
#  'death',
#  'debut',
#  'decad',
#  'decay',
#  'deceas',
#  'decid',
#  'decor',
#  'dedic',
#  'dee',
#  'deem',
#  'deep',
#  'defeat',
#  'defect',
#  'defend',
#  'defens',
#  'deiti',
#  'del',
#  'delroy',
#  'delvadian',
#  'demara',
#  'demogoblin',
#  'demon',
#  'demonstr',
#  'depart',
#  'deriv',
#  'descend',
#  'describ',
#  'design',
#  'despit',
#  'despond',
#  'despot',
#  'destin',
#  'destroy',
#  'destruct',
#  'detail',
#  'determin',
#  'devast',
#  'develop',
#  'deviat',
#  'devic',
#  'devil',
#  'devis',
#  'devour',
#  'diamond',
#  'dictat',
#  'dictatorship',
#  'die',
#  'differ',
#  'dimens',
#  'dinosaur',
#  'direct',
#  'directli',
#  'director',
#  'dirk',
#  'disapprov',
#  'disast',
#  'discard',
#  'discipl',
#  'discov',
#  'disgruntl',
#  'disguis',
#  'distanc',
#  'distant',
#  'disturb',
#  'divert',
#  'doctor',
#  'dog',
#  'doll',
#  'dollar',
#  'don',
#  'donat',
#  'donna',
#  'doom',
#  'dorca',
#  'doreen',
#  'dormammu',
#  'dorrek',
#  'dose',
#  'downsiz',
#  'dozen',
#  'draft',
#  'drago',
#  'dragon',
#  'drax',
#  'dream',
#  'drew',
#  'drug',
#  'dub',
#  'ductor',
#  'dude',
#  'due',
#  'duplic',
#  'durabl',
#  'dure',
#  'dwarfish',
#  'dynamo',
#  'dyne',
#  'eager',
#  'earli',
#  'earlier',
#  'earn',
#  'earth',
#  'earthl',
#  'eas',
#  'eat',
#  'eddi',
#  'edi',
#  'edward',
#  'effect',
#  'effort',
#  'ego',
#  'eight',
#  'eighti',
#  'eisenhow',
#  'elder',
#  'eldest',
#  'electrolyt',
#  'electron',
#  'elektra',
#  'elev',
#  'elimin',
#  'eliot',
#  'elit',
#  'elizabeth',
#  'elli',
#  'embark',
#  'embodi',
#  'emerg',
#  'emil',
#  'emma',
#  'emot',
#  'emperor',
#  'empir',
#  'employ',
#  'empow',
#  'enabl',
#  'enamor',
#  'enchant',
#  'encount',
#  'end',
#  'endow',
#  'endur',
#  'enemi',
#  'energi',
#  'enforc',
#  'engin',
#  'english',
#  'enhanc',
#  'enigmat',
#  'enlist',
#  'enough',
#  'enrol',
#  'ensur',
#  'enthusiasm',
#  'enthusiast',
#  'entir',
#  'entiti',
#  'envi',
#  'environ',
#  'ero',
#  'escap',
#  'eskimo',
#  'especi',
#  'espinosa',
#  'esteem',
#  'etern',
#  'european',
#  'eve',
#  'even',
#  'event',
#  'eventu',
#  'ever',
#  'everett',
#  'everi',
#  'everyth',
#  'evil',
#  'evolutionari',
#  'exact',
#  'exactli',
#  'excalibur',
#  'except',
#  'exchang',
#  'excit',
#  'execution',
#  'exhibit',
#  'exist',
#  'exorc',
#  'experi',
#  'experienc',
#  'expert',
#  'explor',
#  'explos',
#  'expos',
#  'exposur',
#  'extend',
#  'extent',
#  'extermin',
#  'extra',
#  'extract',
#  'extranorm',
#  'extraordinari',
#  'eye',
#  'fabl',
#  'face',
#  'facsimil',
#  'fact',
#  'faction',
#  'facto',
#  'fail',
#  'fairli',
#  'falcon',
#  'fall',
#  'fallen',
#  'fals',
#  'falsworth',
#  'faltin',
#  'famili',
#  'famou',
#  'fan',
#  'fantast',
#  'farouk',
#  'fast',
#  'fatal',
#  'fate',
#  'father',
#  'favor',
#  'fbi',
#  'fear',
#  'fearless',
#  'feder',
#  'feel',
#  'feet',
#  'felin',
#  'fell',
#  'fellow',
#  'felt',
#  'femal',
#  'feroci',
#  'fianc',
#  'field',
#  'fierc',
#  'fight',
#  'fighter',
#  'figur',
#  'file',
#  'fill',
#  'film',
#  'find',
#  'fire',
#  'firearm',
#  'first',
#  'fisk',
#  'fission',
#  'fist',
#  'fit',
#  'five',
#  'fixer',
#  'flamboy',
#  'flame',
#  'flash',
#  'flashi',
#  'flechett',
#  'fled',
#  'fli',
#  'flight',
#  'flock',
#  'focus',
#  'foe',
#  'follow',
#  'fond',
#  'for',
#  'forc',
#  'ford',
#  'foretold',
#  'forg',
#  'form',
#  'former',
#  'formerli',
#  'formid',
#  'formula',
#  'fought',
#  'found',
#  'foundat',
#  'founder',
#  'four',
#  'fox',
#  'frail',
#  'franklin',
#  'freak',
#  'freakish',
#  'free',
#  'freedom',
#  'friction',
#  'friend',
#  'friendship',
#  'fritz',
#  'front',
#  'frost',
#  'frustrat',
#  'fulfil',
#  'full',
#  'fulli',
#  'fun',
#  'function',
#  'fund',
#  'furi',
#  'futur',
#  'gain',
#  'galactu',
#  'galaxi',
#  'gallio',
#  'game',
#  'gamma',
#  'gamora',
#  'garden',
#  'gargan',
#  'garrett',
#  'garth',
#  'garthwait',
#  'gath',
#  'gather',
#  'gatl',
#  'gauntlet',
#  'gave',
#  'gaveedra',
#  'gener',
#  'genet',
#  'genghi',
#  'geni',
#  'geniu',
#  'genius',
#  'georg',
#  'german',
#  'germani',
#  'get',
#  'ghost',
#  'giant',
#  'gibney',
#  'gift',
#  'gigantu',
#  'girl',
#  'girlfriend',
#  'give',
#  'given',
#  'gleason',
#  'glenn',
#  'glue',
#  'go',
#  'god',
#  'goddess',
#  'godfath',
#  'goe',
#  'gold',
#  'goliath',
#  'golmen',
#  'good',
#  'got',
#  'govern',
#  'graduat',
#  'graft',
#  'grandeur',
#  'grandfath',
#  'grandmast',
#  'grandmoth',
#  'grant',
#  'grave',
#  'great',
#  'greatest',
#  'green',
#  'greer',
#  'gregor',
#  'grew',
#  'grey',
#  'grimm',
#  'groot',
#  'grotesqu',
#  'group',
#  'groupi',
#  'grow',
#  'grown',
#  'guard',
#  'guardian',
#  'guardsmen',
#  'guid',
#  'guido',
#  'guilt',
#  'guis',
#  'gun',
#  'gunnar',
#  'guy',
#  'gwen',
#  'gyp',
#  'hair',
#  'half',
#  'hammer',
#  'hand',
#  'hank',
#  'happen',
#  'har',
#  'harada',
#  'hard',
#  'hardest',
#  'harlem',
#  'harmon',
#  'harrelson',
#  'harrison',
#  'harsh',
#  'hate',
#  'hawkey',
#  'he',
#  'head',
#  'heal',
#  'heart',
#  'heather',
#  'heavili',
#  'hector',
#  'heighten',
#  'heir',
#  'held',
#  'hell',
#  'hellfir',
#  'hellip',
#  'helmet',
#  'helmut',
#  'help',
#  'henri',
#  'her',
#  'herald',
#  'herman',
#  'hero',
#  'heroic',
#  'hi',
#  'hidden',
#  'hide',
#  'high',
#  'highli',
#  'hire',
#  'hiroshima',
#  'hit',
#  'hobgoblin',
#  'hogzilla',
#  'hold',
#  'holograph',
#  'home',
#  'homeland',
#  'homework',
#  'homo',
#  'hone',
#  'honor',
#  'hook',
#  'hope',
#  'hopeless',
#  'hord',
#  'horrif',
#  'horrifi',
#  'horseman',
#  'host',
#  'hostag',
#  'hound',
#  'hous',
#  'howev',
#  'howlett',
#  'hudson',
#  'huge',
#  'hulk',
#  'hulkbust',
#  'human',
#  'humankind',
#  'humanoid',
#  'hunter',
#  'hurt',
#  'husband',
#  'hybrid',
#  'hydra',
#  'hydraul',
#  'hyperact',
#  'idea',
#  'ident',
#  'ii',
#  'il',
#  'ill',
#  'illeg',
#  'illegitim',
#  'illinoi',
#  'imag',
#  'imbecil',
#  'immatur',
#  'immedi',
#  'immigr',
#  'immort',
#  'impenetr',
#  'imperi',
#  'implant',
#  'imprint',
#  'imprison',
#  'improvis',
#  ...]

# %%
bagOfWordsModel.get_feature_names()[1005]
# Out:
# 'includ'

# %% [markdown]
# #**2 Búsqueda de los personajes más similares a una persona**

# %% [markdown]
# ##**2.1 Basado únicamente en descripción**

# %% [markdown]
# Para realizar este proceso hay que realizar todo el proceso anterior incluyendo a la persona con su descripción. De esta forma, se calculará la distancia entre el usuario y todos los personajes.

# %% [markdown]
# En la siguiente celda se debe intrroducir el nombre y la descripción con la que se quiera calcular la distancia

# %%
nombre = "Pepe" #Introducir nombre
descripcion = "Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist" #Descripcion

# %% [markdown]
# Se realiza el mismo proceso que en el punto 1

# %%
import pandas as pd

originalData = pd.read_csv('marvel.csv')
originalData = originalData.append({'name' : nombre, 'description' : descripcion}, ignore_index=True)
originalData
# Out:
#                            name                                        description
# 0                  A-Bomb (HAS)  Rick Jones has been Hulk's best bud since day ...
# 1                        A.I.M.  AIM is a terrorist organization bent on destro...
# 2    Abomination (Emil Blonsky)  Formerly known as Emil Blonsky, a spy of Sovie...
# 3                  Adam Warlock  Adam Warlock is an artificially created human ...
# 4                Agent X (Nijo)  Originally a partner of the mind-altering assa...
# ..                          ...                                                ...
# 277                      Zodiak  Twelve demons merged with Norman Harrison, who...
# 278        Zombie (Simon Garth)  War hero Simon Garth was turned into a zombie ...
# 279                       Zuras         Zuras was once the leader of the Eternals.
# 280                       Zzzax  A chain reaction in an atomic reactor, a resul...
# 281                        Pepe  Pepe was once the leader of the Eternals. He i...
#
# [282 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
nltk.download('punkt')
nltk.download('stopwords')

ps = PorterStemmer()

preprocessedText = []

for row in originalData.itertuples():
    text = word_tokenize(row[2]) ## indice de la columna que contiene la descripcion
    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [ps.stem(w) for w in text if not w in stops and w.isalnum()]
    text = " ".join(text)
    
    preprocessedText.append(text)

preprocessedData = originalData
preprocessedData['processed_text'] = preprocessedText

preprocessedData
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                            name  ...                                     processed_text
# 0                  A-Bomb (HAS)  ...  rick jone hulk best bud sinc day one friend te...
# 1                        A.I.M.  ...             aim terrorist organ bent destroy world
# 2    Abomination (Emil Blonsky)  ...  formerli known emil blonski spi soviet yugosla...
# 3                  Adam Warlock  ...  adam warlock artifici creat human born cocoon ...
# 4                Agent X (Nijo)  ...  origin partner assassin black swan nijo spi de...
# ..                          ...  ...                                                ...
# 277                      Zodiak  ...  twelv demon merg norman harrison soon adopt gu...
# 278        Zombie (Simon Garth)  ...  war hero simon garth turn zombi secretari layl...
# 279                       Zuras  ...                                  zura leader etern
# 280                       Zzzax  ...  A chain reaction atom reactor result terrorist...
# 281                        Pepe  ...  pepe leader etern He strong iron small ant He ...
#
# [282 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

bagOfWordsModel = TfidfVectorizer()
bagOfWordsModel.fit(preprocessedData['processed_text'])
textsBoW= bagOfWordsModel.transform(preprocessedData['processed_text'])

# %% [markdown]
# A continuación se crea una matriz N x N (N= número de personajes) en donde el valor de la posición matriz[ i , j ] indique la distancia que existe entre el personaje i y el personaje j.

# %%
from sklearn.metrics import pairwise_distances

distance_matrix= pairwise_distances(textsBoW,textsBoW ,metric='cosine')

# %% [markdown]
# Ahora basta con obtener el índice de la persona introducida y las distancias con el resto de personajes

# %%
indexOfTitle = preprocessedData[preprocessedData['name']==nombre].index.values[0]
indexOfTitle

distance_scores = list(enumerate(distance_matrix[indexOfTitle]))
distance_scores
# Out:
# [(0, 0.9429037594051554),
#  (1, 0.8737492680194615),
#  (2, 1.0),
#  (3, 1.0),
#  (4, 1.0),
#  (5, 0.9566567344748318),
#  (6, 1.0),
#  (7, 1.0),
#  (8, 0.9481970831793141),
#  (9, 1.0),
#  (10, 0.9421206203190599),
#  (11, 1.0),
#  (12, 1.0),
#  (13, 1.0),
#  (14, 1.0),
#  (15, 1.0),
#  (16, 1.0),
#  (17, 1.0),
#  (18, 1.0),
#  (19, 0.8838856415313219),
#  (20, 1.0),
#  (21, 1.0),
#  (22, 1.0),
#  (23, 1.0),
#  (24, 1.0),
#  (25, 1.0),
#  (26, 1.0),
#  (27, 1.0),
#  (28, 1.0),
#  (29, 1.0),
#  (30, 1.0),
#  (31, 1.0),
#  (32, 1.0),
#  (33, 1.0),
#  (34, 1.0),
#  (35, 1.0),
#  (36, 1.0),
#  (37, 1.0),
#  (38, 0.9299958674731036),
#  (39, 1.0),
#  (40, 0.9478446467461085),
#  (41, 0.9549177211043653),
#  (42, 0.9189019686961419),
#  (43, 0.9223008745731874),
#  (44, 1.0),
#  (45, 1.0),
#  (46, 1.0),
#  (47, 0.9511172137781917),
#  (48, 1.0),
#  (49, 1.0),
#  (50, 0.9514025527164229),
#  (51, 1.0),
#  (52, 1.0),
#  (53, 1.0),
#  (54, 1.0),
#  (55, 1.0),
#  (56, 1.0),
#  (57, 0.9497235166279826),
#  (58, 0.9343482964519906),
#  (59, 1.0),
#  (60, 1.0),
#  (61, 1.0),
#  (62, 1.0),
#  (63, 1.0),
#  (64, 1.0),
#  (65, 1.0),
#  (66, 1.0),
#  (67, 1.0),
#  (68, 1.0),
#  (69, 1.0),
#  (70, 0.9261745123469376),
#  (71, 0.9006089724959818),
#  (72, 1.0),
#  (73, 1.0),
#  (74, 1.0),
#  (75, 1.0),
#  (76, 1.0),
#  (77, 1.0),
#  (78, 1.0),
#  (79, 1.0),
#  (80, 1.0),
#  (81, 0.9456947338532178),
#  (82, 1.0),
#  (83, 1.0),
#  (84, 1.0),
#  (85, 1.0),
#  (86, 1.0),
#  (87, 1.0),
#  (88, 1.0),
#  (89, 1.0),
#  (90, 1.0),
#  (91, 1.0),
#  (92, 1.0),
#  (93, 1.0),
#  (94, 1.0),
#  (95, 1.0),
#  (96, 1.0),
#  (97, 1.0),
#  (98, 1.0),
#  (99, 1.0),
#  (100, 1.0),
#  (101, 0.9411151438454797),
#  (102, 1.0),
#  (103, 1.0),
#  (104, 1.0),
#  (105, 1.0),
#  (106, 1.0),
#  (107, 1.0),
#  (108, 1.0),
#  (109, 1.0),
#  (110, 1.0),
#  (111, 1.0),
#  (112, 1.0),
#  (113, 1.0),
#  (114, 1.0),
#  (115, 1.0),
#  (116, 1.0),
#  (117, 1.0),
#  (118, 1.0),
#  (119, 1.0),
#  (120, 1.0),
#  (121, 1.0),
#  (122, 0.9534922697984229),
#  (123, 1.0),
#  (124, 1.0),
#  (125, 1.0),
#  (126, 0.9089324712744773),
#  (127, 1.0),
#  (128, 1.0),
#  (129, 1.0),
#  (130, 1.0),
#  (131, 1.0),
#  (132, 1.0),
#  (133, 1.0),
#  (134, 1.0),
#  (135, 1.0),
#  (136, 0.9529566705122121),
#  (137, 1.0),
#  (138, 1.0),
#  (139, 1.0),
#  (140, 0.9353501019861358),
#  (141, 1.0),
#  (142, 1.0),
#  (143, 1.0),
#  (144, 1.0),
#  (145, 1.0),
#  (146, 1.0),
#  (147, 1.0),
#  (148, 1.0),
#  (149, 1.0),
#  (150, 1.0),
#  (151, 1.0),
#  (152, 1.0),
#  (153, 0.9434001866332543),
#  (154, 1.0),
#  (155, 1.0),
#  (156, 1.0),
#  (157, 1.0),
#  (158, 1.0),
#  (159, 1.0),
#  (160, 1.0),
#  (161, 1.0),
#  (162, 1.0),
#  (163, 1.0),
#  (164, 1.0),
#  (165, 1.0),
#  (166, 1.0),
#  (167, 1.0),
#  (168, 1.0),
#  (169, 1.0),
#  (170, 0.8481911415562455),
#  (171, 0.8000775160378006),
#  (172, 1.0),
#  (173, 1.0),
#  (174, 0.927804124283846),
#  (175, 1.0),
#  (176, 0.8685070563769115),
#  (177, 0.9208233862525436),
#  (178, 1.0),
#  (179, 1.0),
#  (180, 0.9311798620576808),
#  (181, 1.0),
#  (182, 1.0),
#  (183, 1.0),
#  (184, 1.0),
#  (185, 1.0),
#  (186, 1.0),
#  (187, 1.0),
#  (188, 1.0),
#  (189, 1.0),
#  (190, 1.0),
#  (191, 1.0),
#  (192, 1.0),
#  (193, 1.0),
#  (194, 1.0),
#  (195, 1.0),
#  (196, 1.0),
#  (197, 1.0),
#  (198, 1.0),
#  (199, 1.0),
#  (200, 1.0),
#  (201, 1.0),
#  (202, 1.0),
#  (203, 1.0),
#  (204, 1.0),
#  (205, 1.0),
#  (206, 1.0),
#  (207, 1.0),
#  (208, 1.0),
#  (209, 1.0),
#  (210, 1.0),
#  (211, 0.9573268303684124),
#  (212, 1.0),
#  (213, 1.0),
#  (214, 1.0),
#  (215, 1.0),
#  (216, 0.929035759891847),
#  (217, 1.0),
#  (218, 1.0),
#  (219, 1.0),
#  (220, 0.9380952999448944),
#  (221, 1.0),
#  (222, 1.0),
#  (223, 1.0),
#  (224, 1.0),
#  (225, 1.0),
#  (226, 1.0),
#  (227, 1.0),
#  (228, 1.0),
#  (229, 1.0),
#  (230, 1.0),
#  (231, 1.0),
#  (232, 1.0),
#  (233, 1.0),
#  (234, 1.0),
#  (235, 1.0),
#  (236, 1.0),
#  (237, 1.0),
#  (238, 1.0),
#  (239, 1.0),
#  (240, 1.0),
#  (241, 1.0),
#  (242, 1.0),
#  (243, 1.0),
#  (244, 1.0),
#  (245, 1.0),
#  (246, 1.0),
#  (247, 1.0),
#  (248, 1.0),
#  (249, 1.0),
#  (250, 1.0),
#  (251, 1.0),
#  (252, 1.0),
#  (253, 0.9680501546723466),
#  (254, 1.0),
#  (255, 1.0),
#  (256, 1.0),
#  (257, 1.0),
#  (258, 1.0),
#  (259, 1.0),
#  (260, 1.0),
#  (261, 1.0),
#  (262, 1.0),
#  (263, 1.0),
#  (264, 1.0),
#  (265, 1.0),
#  (266, 1.0),
#  (267, 1.0),
#  (268, 1.0),
#  (269, 1.0),
#  (270, 1.0),
#  (271, 1.0),
#  (272, 0.9420145462520628),
#  (273, 1.0),
#  (274, 1.0),
#  (275, 1.0),
#  (276, 1.0),
#  (277, 1.0),
#  (278, 1.0),
#  (279, 0.720027498092748),
#  (280, 0.9351049394360071),
#  (281, 0.0)]

# %% [markdown]
# Una vez tenemos las distancias, únicamente debemos ordenarlas, quedarnos con las más cortas y mostrarlas de forma legible.

# %%
ordered_scores = sorted(distance_scores, key=lambda x: x[1])
top_scores = ordered_scores[1:11]
top_indexes = [i[0] for i in top_scores]
preprocessedData['name'].iloc[top_indexes]
# Out:
# 279                                 Zuras
# 171                                 Thena
# 170                      The Leader (HAS)
# 176                            Thor (MAA)
# 1                                  A.I.M.
# 19     Captain America/Steve Rogers (MAA)
# 71                            Shadow King
# 126                                Sprite
# 42              Iron Man/Tony Stark (MAA)
# 177                       Thor (Ultimate)
# Name: name, dtype: object

# %% [markdown]
# ##**2.2 Basado en su descripción y parámetros adicionales**

# %% [markdown]
# **Búsqueda basada en Descripción + Valoración Comentarios + Valoración Directa (Likes) + Valoración Media Comentarios**
#
# Ponderación:
#
# * Descripción (70%): se basa en el parecido entre la descripción que tenga el usuario y la descripción de cada personaje
# * Valoración Comentarios (7.5%): se basa en la valoración del comentario textual que realice el usuario a un personaje. Estos valores son extraídos del subsistema de valoración. Puede ser:
#   * Buena (0)
#   * Neutra o no valoración (0.5)
#   * Mala (1)
# * Valoración Directa por Likes (15%)
#   * Like (0)
#   * Dislike (1)
#   * Ninguna (0.5)
# * Valoración Media Comentarios (7.5%): se trata de la media de las valoraciones de comentarios de todos los usuarios sobre un personaje. Puede ser un valor entre 0 y 1.

# %% [markdown]
# Para probar esta parte del sistema simularemos tener los datos de las valoraciones de los comentarios y las valoraciones directas.
#
# A continuación se generan aleatoriamente las valoraciones:
#
# * 0  es valoración positiva
# * 0.5 es valoración neutra (o no valoración)
# * 1 es valoración negativa

# %%
from random import choice, randint

valoracion_comentario = []
valoracion_directa = []
valoracion_media = []

for i in range(0,len(preprocessedData)):
  valoracion_comentario.append(choice([0.0, 0.5, 1.0]))
  valoracion_directa.append(choice([0.0, 0.5, 1.0]))
  valoracion_media.append(randint(0.0,100.0)/100.0)

preprocessedData['valoracion_comentario'] = valoracion_comentario
preprocessedData['valoracion_directa'] = valoracion_directa
preprocessedData['valoracion_media'] = valoracion_media

preprocessedData
# Out:
#                            name  ... valoracion_media
# 0                  A-Bomb (HAS)  ...             0.29
# 1                        A.I.M.  ...             0.22
# 2    Abomination (Emil Blonsky)  ...             0.73
# 3                  Adam Warlock  ...             0.60
# 4                Agent X (Nijo)  ...             0.49
# ..                          ...  ...              ...
# 277                      Zodiak  ...             0.20
# 278        Zombie (Simon Garth)  ...             0.03
# 279                       Zuras  ...             0.71
# 280                       Zzzax  ...             0.15
# 281                        Pepe  ...             0.64
#
# [282 rows x 6 columns]

# %% [markdown]
# A continuación calculamos las distancias teniendo en cuenta la ponderación

# %%
distance_scores_final = []

for i in range(len(distance_matrix[indexOfTitle])):
  valoracion = distance_matrix[indexOfTitle][i]*0.7 + preprocessedData['valoracion_comentario'][i]*0.075 + preprocessedData['valoracion_directa'][i]*0.15 + preprocessedData['valoracion_media'][i]*0.075
  distance_scores_final.append((i,valoracion))

distance_scores_final
# Out:
# [(0, 0.7567826315836087),
#  (1, 0.7781244876136229),
#  (2, 0.9422499999999999),
#  (3, 0.745),
#  (4, 0.9242499999999999),
#  (5, 0.7694097141323822),
#  (6, 0.7809999999999999),
#  (7, 0.9129999999999998),
#  (8, 0.8234879582255199),
#  (9, 0.907),
#  (10, 0.8717344342233418),
#  (11, 0.90925),
#  (12, 0.9392499999999999),
#  (13, 0.73825),
#  (14, 0.8882499999999999),
#  (15, 0.8904999999999998),
#  (16, 0.8739999999999999),
#  (17, 0.92875),
#  (18, 0.9309999999999999),
#  (19, 0.8369699490719252),
#  (20, 0.9159999999999999),
#  (21, 0.835),
#  (22, 0.877),
#  (23, 0.70375),
#  (24, 0.7884999999999999),
#  (25, 0.8829999999999999),
#  (26, 0.8822499999999999),
#  (27, 0.8379999999999999),
#  (28, 0.81175),
#  (29, 0.80275),
#  (30, 0.9024999999999999),
#  (31, 0.8094999999999999),
#  (32, 0.8409999999999999),
#  (33, 0.95275),
#  (34, 0.8124999999999999),
#  (35, 0.8312499999999999),
#  (36, 0.7869999999999999),
#  (37, 0.7779999999999999),
#  (38, 0.8159971072311725),
#  (39, 0.8634999999999999),
#  (40, 0.7737412527222759),
#  (41, 0.8851924047730557),
#  (42, 0.8082313780872993),
#  (43, 0.7453606122012312),
#  (44, 0.8132499999999999),
#  (45, 0.78775),
#  (46, 0.8432499999999998),
#  (47, 0.7182820496447342),
#  (48, 0.8357499999999999),
#  (49, 0.9017499999999998),
#  (50, 0.726731786901496),
#  (51, 0.85075),
#  (52, 0.7705),
#  (53, 0.868),
#  (54, 0.87475),
#  (55, 0.74725),
#  (56, 0.79675),
#  (57, 0.8313064616395878),
#  (58, 0.7425438075163933),
#  (59, 0.72325),
#  (60, 0.82),
#  (61, 0.8267499999999999),
#  (62, 0.8672499999999999),
#  (63, 0.8785),
#  (64, 0.92575),
#  (65, 0.907),
#  (66, 0.8469999999999999),
#  (67, 0.955),
#  (68, 0.9355),
#  (69, 0.8439999999999999),
#  (70, 0.8425721586428563),
#  (71, 0.8389262807471871),
#  (72, 0.7494999999999999),
#  (73, 0.8477499999999999),
#  (74, 0.8604999999999999),
#  (75, 0.8484999999999999),
#  (76, 0.8657499999999999),
#  (77, 0.8552499999999998),
#  (78, 0.8117499999999999),
#  (79, 0.8042499999999999),
#  (80, 0.9115),
#  (81, 0.9004863136972524),
#  (82, 0.8597499999999999),
#  (83, 0.7779999999999999),
#  (84, 0.739),
#  (85, 0.74125),
#  (86, 0.7607499999999999),
#  (87, 0.7374999999999999),
#  (88, 0.8642499999999999),
#  (89, 0.8109999999999999),
#  (90, 0.91975),
#  (91, 0.8357499999999999),
#  (92, 0.8357499999999999),
#  (93, 0.9482499999999999),
#  (94, 0.7314999999999999),
#  (95, 0.8327499999999999),
#  (96, 0.8649999999999999),
#  (97, 0.9159999999999999),
#  (98, 0.74125),
#  (99, 0.9804999999999999),
#  (100, 0.8507499999999999),
#  (101, 0.8687806006918357),
#  (102, 0.9369999999999999),
#  (103, 0.7787499999999999),
#  (104, 0.8619999999999999),
#  (105, 0.7479999999999999),
#  (106, 0.8529999999999999),
#  (107, 0.7884999999999999),
#  (108, 0.7615),
#  (109, 0.7809999999999999),
#  (110, 0.8342499999999999),
#  (111, 0.8109999999999999),
#  (112, 0.7577499999999999),
#  (113, 0.8102499999999999),
#  (114, 0.8762499999999999),
#  (115, 0.9234999999999999),
#  (116, 0.9219999999999998),
#  (117, 0.7779999999999999),
#  (118, 0.976),
#  (119, 0.94675),
#  (120, 0.8664999999999998),
#  (121, 0.91225),
#  (122, 0.804694588858896),
#  (123, 0.988),
#  (124, 0.7689999999999999),
#  (125, 0.78175),
#  (126, 0.725502729892134),
#  (127, 0.8552499999999998),
#  (128, 0.7427499999999999),
#  (129, 0.7914999999999999),
#  (130, 0.8627499999999999),
#  (131, 0.70075),
#  (132, 0.9197499999999998),
#  (133, 0.9017499999999998),
#  (134, 0.9129999999999998),
#  (135, 0.80875),
#  (136, 0.7120696693585483),
#  (137, 0.7104999999999999),
#  (138, 0.8147499999999999),
#  (139, 0.862),
#  (140, 0.671245071390295),
#  (141, 0.8837499999999998),
#  (142, 0.7427499999999999),
#  (143, 0.7899999999999999),
#  (144, 0.74725),
#  (145, 0.9355),
#  (146, 0.94),
#  (147, 0.7892499999999999),
#  (148, 0.8079999999999999),
#  (149, 0.8207499999999999),
#  (150, 0.7509999999999999),
#  (151, 0.9249999999999998),
#  (152, 0.7449999999999999),
#  (153, 0.7466301306432779),
#  (154, 0.8477499999999999),
#  (155, 0.98125),
#  (156, 0.7945),
#  (157, 0.8657499999999999),
#  (158, 0.7974999999999999),
#  (159, 0.7607499999999999),
#  (160, 0.9197499999999998),
#  (161, 0.7419999999999999),
#  (162, 0.9647499999999999),
#  (163, 0.9084999999999999),
#  (164, 0.9624999999999999),
#  (165, 0.7772499999999999),
#  (166, 0.94),
#  (167, 0.8889999999999999),
#  (168, 0.93175),
#  (169, 0.9917499999999999),
#  (170, 0.7812337990893717),
#  (171, 0.8060542612264604),
#  (172, 0.78175),
#  (173, 0.8484999999999999),
#  (174, 0.6899628869986921),
#  (175, 0.7795),
#  (176, 0.650704939463838),
#  (177, 0.8688263703767805),
#  (178, 0.7727499999999999),
#  (179, 0.82),
#  (180, 0.7823259034403764),
#  (181, 0.9062499999999999),
#  (182, 0.742),
#  (183, 0.8109999999999999),
#  (184, 0.8935),
#  (185, 0.90625),
#  (186, 0.7074999999999999),
#  (187, 0.766),
#  (188, 0.8349999999999999),
#  (189, 0.8604999999999999),
#  (190, 0.92275),
#  (191, 0.8387499999999999),
#  (192, 0.92125),
#  (193, 0.748),
#  (194, 0.8657499999999999),
#  (195, 0.96175),
#  (196, 0.721),
#  (197, 0.7974999999999999),
#  (198, 0.826),
#  (199, 0.8005),
#  (200, 0.817),
#  (201, 0.9324999999999999),
#  (202, 0.718),
#  (203, 0.72475),
#  (204, 0.9242499999999999),
#  (205, 0.8852499999999999),
#  (206, 0.9062499999999999),
#  (207, 0.9129999999999999),
#  (208, 0.87625),
#  (209, 0.8499999999999999),
#  (210, 0.9144999999999999),
#  (211, 0.7128787812578886),
#  (212, 0.841),
#  (213, 0.7779999999999999),
#  (214, 0.8102499999999999),
#  (215, 0.7959999999999999),
#  (216, 0.7013250319242927),
#  (217, 0.91075),
#  (218, 0.8102499999999999),
#  (219, 0.9309999999999999),
#  (220, 0.8074167099614261),
#  (221, 0.8574999999999999),
#  (222, 0.9302499999999999),
#  (223, 0.8739999999999999),
#  (224, 0.85),
#  (225, 0.91075),
#  (226, 0.79975),
#  (227, 0.958),
#  (228, 0.8364999999999999),
#  (229, 0.7434999999999999),
#  (230, 0.9422499999999999),
#  (231, 0.8927499999999999),
#  (232, 0.77125),
#  (233, 0.8769999999999999),
#  (234, 0.7727499999999999),
#  (235, 0.7517499999999999),
#  (236, 0.7705),
#  (237, 0.89425),
#  (238, 0.71275),
#  (239, 0.943),
#  (240, 0.9415),
#  (241, 0.9309999999999999),
#  (242, 0.9039999999999999),
#  (243, 0.95275),
#  (244, 0.8544999999999998),
#  (245, 0.9452499999999999),
#  (246, 0.9295),
#  (247, 0.7944999999999999),
#  (248, 0.72325),
#  (249, 0.8132499999999999),
#  (250, 0.9249999999999999),
#  (251, 0.97225),
#  (252, 0.7764999999999999),
#  (253, 0.9423851082706425),
#  (254, 0.7749999999999999),
#  (255, 0.7509999999999999),
#  (256, 0.8012499999999999),
#  (257, 0.9542499999999999),
#  (258, 0.8259999999999998),
#  (259, 0.7397499999999999),
#  (260, 0.946),
#  (261, 0.7479999999999999),
#  (262, 0.7862499999999999),
#  (263, 0.72475),
#  (264, 0.9302499999999999),
#  (265, 0.8079999999999999),
#  (266, 0.943),
#  (267, 0.8612499999999998),
#  (268, 0.73825),
#  (269, 0.946),
#  (270, 0.7164999999999999),
#  (271, 0.7982499999999999),
#  (272, 0.8716601823764439),
#  (273, 0.904),
#  (274, 0.9707499999999999),
#  (275, 0.9249999999999999),
#  (276, 0.8282499999999999),
#  (277, 0.715),
#  (278, 0.7772499999999999),
#  (279, 0.7072692486649236),
#  (280, 0.8533234576052049),
#  (281, 0.08549999999999999)]

# %% [markdown]
# A continuación nos quedamos con los personajes más aprecidos

# %%
ordered_scores_final = sorted(distance_scores_final, key=lambda x: x[1])
top_scores_final = ordered_scores_final[1:11]
top_indexes_final = [i[0] for i in top_scores_final]
preprocessedData['name'].iloc[top_indexes_final]
# Out:
# 176                   Thor (MAA)
# 140    Storm (Age of Apocalypse)
# 174                         Thor
# 131                      Starfox
# 216                      Vampiro
# 23                  Colleen Wing
# 279                        Zuras
# 186                     Timeslip
# 137        Stilt-Man (Wibur Day)
# 136                        Stick
# Name: name, dtype: object

# %% [markdown]
# #**3. Resumen de los resultados**

# %% [markdown]
# **Resultados del punto 2.1**: se muestran a continuación las descripciones para comprobar que existe algún parecido

# %%
descripcion
# Out:
# 'Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist'

# %%
preprocessedData['name'].iloc[top_indexes]
# Out:
# 279                                 Zuras
# 171                                 Thena
# 170                      The Leader (HAS)
# 176                            Thor (MAA)
# 1                                  A.I.M.
# 19     Captain America/Steve Rogers (MAA)
# 71                            Shadow King
# 126                                Sprite
# 42              Iron Man/Tony Stark (MAA)
# 177                       Thor (Ultimate)
# Name: name, dtype: object

# %%
preprocessedData['description'].iloc[top_indexes]
# Out:
# 279           Zuras was once the leader of the Eternals.
# 171    Thena, a second generation Eternal, is the eld...
# 170    What the Hulk has in strength, the Leader has ...
# 176    Thor is the Asgardian Prince of Thunder, the s...
# 1      AIM is a terrorist organization bent on destro...
# 19     During World War II, Steve Rogers enlisted in ...
# 71     One of the oldest and more powerful mutants ev...
# 126    Sprite is a mischievous Eternal who maintains ...
# 42     Tony Stark is the genius inventor/billionaire/...
# 177    He claims he is the legendary Norse thunder de...
# Name: description, dtype: object

# %% [markdown]
# **Resultados del punto 2.2**: se muestran a continuación las descripciones para comprobar que existe algún parecido (se debe tener en este caso la descripción no tiene todo el peso del cálculo)

# %%
descripcion
# Out:
# 'Pepe was once the leader of the Eternals. He is strong as iron and as small as an ant. He is a terrorist'

# %%
preprocessedData['name'].iloc[top_indexes_final]
# Out:
# 176                   Thor (MAA)
# 140    Storm (Age of Apocalypse)
# 174                         Thor
# 131                      Starfox
# 216                      Vampiro
# 23                  Colleen Wing
# 279                        Zuras
# 186                     Timeslip
# 137        Stilt-Man (Wibur Day)
# 136                        Stick
# Name: name, dtype: object

# %%
preprocessedData['description'].iloc[top_indexes_final]
# Out:
# 176    Thor is the Asgardian Prince of Thunder, the s...
# 140    Calling herself the Windrider, Storm carved ou...
# 174    As the Norse God of thunder and lightning, Tho...
# 131    The youngest son of Mentor and Sui-San, Eros h...
# 216    Vampiro, part of the race known as the Eternal...
# 23     Colleen Wing was raised in Japan by her grandf...
# 279           Zuras was once the leader of the Eternals.
# 186    As a young child, Rina Patel experienced visio...
# 137    Wilbur Day was a scientist at Kaxton Labs who ...
# 136    Stick, who trained both Daredevil and Elektra ...
# Name: description, dtype: object
